# %% [markdown]
# # Movie Genie: Plan the perfect trip to the movies with just one click!
# By Kathleen, Rachel, Stephanie, and Zeeshan

# %% [markdown]
# Below you will find the backend code that we used to build our website Movie Genie.  Movie Genie asks the user a few questions about their day, analyzes their answers to predict their mood, and then displays showtimes at the nearest theaters for the movies that best fit their mood.  Having all results displayed in one place means less clicking around from website to website trying to find the best movie/showtime for you, and the sentiment analysis helps you decide what movie you should see.  MoviePass has made going to the movies trendy again, and with so many options out there (especially in NYC), we want to make the moviegoing process as easy as possible.

# %% [markdown]
# ### Preparation

# %%
import pandas as pd
import requests
from datetime import datetime
from pytz import timezone
import json

est = timezone('US/Eastern')

# %% [markdown]
# ### Showtimes of a selected genre in a specific zipcode

# %% [markdown]
# #### Get all cinemas in NYC

# %% [markdown]
# To get all cinemas in NYC listed in the ishowtimes API, we make a call to the ishowtimes API using the city_id parameter for New York City to get an array containing all the cinemas in New York City.

# %%
ishowtimes_url = "https://api.internationalshowtimes.com/v4/cinemas"
parameters = {'city_id': '2215'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}

NYCcinemas = (requests.get(ishowtimes_url, params=parameters, headers=headers).json())['cinemas']
NYCcinemas
# Out:
# [{'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41514',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '234 W 42nd St, New York, NY 10036, United States',
#     'house': '234',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'West 42nd Street',
#     'zipcode': '10036'},
#    'lat': 40.7567668,
#    'lon': -73.9892626},
#   'name': 'AMC Empire 25',
#   'slug': 'amc-empire-25-new-york',
#   'telephone': '(212) 398-2597',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-empire-25'},
#  {'booking_type': 'external',
#   'chain_id': '27',
#   'id': '41523',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '850 Broadway, New York, NY 10003, United States',
#     'house': '850',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'Broadway',
#     'zipcode': '10003'},
#    'lat': 40.7340673,
#    'lon': -73.9908232},
#   'name': 'Regal Union Square Stadium 14',
#   'slug': 'regal-union-square-stadium-14',
#   'telephone': '(844) 462-7342 ext 628',
#   'website': 'http://www.regmovies.com/theaters/regal-union-square-stadium-14/5315'},
#  {'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41527',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '312 W 34th St, New York, NY 10001, United States',
#     'house': '312',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'West 34th Street',
#     'zipcode': '10001'},
#    'lat': 40.7524199,
#    'lon': -73.9944354},
#   'name': 'AMC Loews 34th Street 14',
#   'slug': 'amc-loews-34th-street-14-new-york',
#   'telephone': '(212) 244-4556',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-loews-34th-street-14'},
#  {'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41529',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '2309 Frederick Douglass Blvd, New York, NY 10027, United States',
#     'house': '2309',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'Frederick Douglass Boulevard',
#     'zipcode': '10027'},
#    'lat': 40.8096863,
#    'lon': -73.9517817},
#   'name': 'AMC Magic Johnson Harlem 9',
#   'slug': 'amc-magic-johnson-harlem-9-new-york',
#   'telephone': '(212) 665-6923',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-magic-johnson-harlem-9'},
#  {'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41530',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '570 Second Avenue, New York, NY 10016, United States',
#     'house': '570',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'Second Avenue',
#     'zipcode': '10016'},
#    'lat': 40.7428531,
#    'lon': -73.9766857},
#   'name': 'AMC Kips Bay 15',
#   'slug': 'amc-loews-kips-bay-15-new-york',
#   'telephone': '(212) 447-0638',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-loews-kips-bay-15'},
#  {'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41531',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '66 Third Ave (11th St.), New York, NY 10003, United States',
#     'house': None,
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': None,
#     'zipcode': '10003'},
#    'lat': 40.73162,
#    'lon': -73.988815},
#   'name': 'AMC Village 7',
#   'slug': 'amc-village-7-new-york',
#   'telephone': '(212) 982-2116',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-village-7'},
#  {'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41532',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '1998 Broadway, New York, NY 10023, United States',
#     'house': '1998',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'Broadway',
#     'zipcode': '10023'},
#    'lat': 40.7751083,
#    'lon': -73.9817906},
#   'name': 'AMC Loews Lincoln Square 13',
#   'slug': 'amc-loews-lincoln-square-13-new-york',
#   'telephone': '(212) 336-5020',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-loews-lincoln-square-13'},
#  {'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41533',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '890 Broadway, New York, NY 10003, United States',
#     'house': '890',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'Broadway',
#     'zipcode': '10003'},
#    'lat': 40.7385554,
#    'lon': -73.989669},
#   'name': 'AMC Loews 19th St. East 6',
#   'slug': 'amc-loews-19th-st-east-6-new-york',
#   'telephone': '(212) 260-8173',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-loews-19th-st-east-6'},
#  {'booking_type': 'external',
#   'chain_id': '27',
#   'id': '41534',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '102 North End Ave, New York, NY 10281, United States',
#     'house': '102',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'North End Avenue',
#     'zipcode': '10281'},
#    'lat': 40.714989,
#    'lon': -74.015236},
#   'name': 'Regal Battery Park Stadium 11',
#   'slug': 'regal-battery-park-stadium-11',
#   'telephone': '(844) 462-7342 ext 629',
#   'website': 'http://www.regmovies.com/theaters/regal-battery-park-stadium-11/7333'},
#  {'booking_type': None,
#   'chain_id': '270',
#   'id': '41535',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '181-, 189 2nd Ave, New York, NY 10003, United States',
#     'house': '189',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': '2nd Avenue',
#     'zipcode': '10003'},
#    'lat': 40.7309555,
#    'lon': -73.9862117},
#   'name': 'Village East Cinema',
#   'slug': 'village-east-cinema-new-york',
#   'telephone': '(212) 529-6998',
#   'website': 'https://www.citycinemas.com/villageeast'},
#  {'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41542',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '1538 Third Ave (86th St.), New York, NY 10028, United States',
#     'house': None,
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': None,
#     'zipcode': '10028'},
#    'lat': 40.779406,
#    'lon': -73.954065},
#   'name': 'AMC Loews Orpheum 7',
#   'slug': 'amc-loews-orpheum-7-new-york',
#   'telephone': '(212) 876-2111',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-loews-orpheum-7'},
#  {'booking_type': 'external',
#   'chain_id': '26',
#   'id': '41544',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '2310 Broadway, New York, NY 10024, United States',
#     'house': '2310',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'Broadway',
#     'zipcode': '10024'},
#    'lat': 40.7867135,
#    'lon': -73.9773929},
#   'name': 'AMC 84th Street 6',
#   'slug': 'amc-84th-street-6-new-york',
#   'telephone': '(212) 721-6023',
#   'website': 'https://www.amctheatres.com/movie-theatres/new-york-city/amc-84th-street-6'},
#  {'booking_type': None,
#   'chain_id': '270',
#   'id': '41554',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '210 E 86th St, New York, NY 10028, United States',
#     'house': '210',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'East 86th Street',
#     'zipcode': '10028'},
#    'lat': 40.7782859,
#    'lon': -73.9534088},
#   'name': 'East 86th St. Cinema',
#   'slug': 'east-86th-st-cinema-new-york',
#   'telephone': '(212) 734-4427',
#   'website': 'https://www.citycinemas.com/east86thst'},
#  {'booking_type': None,
#   'chain_id': '270',
#   'id': '56382',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '1271 2nd Ave., @ 66th St., New York, NY, 10021',
#     'house': '1271',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'Second Avenue',
#     'zipcode': None},
#    'lat': 37.09024,
#    'lon': -95.712891},
#   'name': 'City Cinemas Beekman Theatre',
#   'slug': 'city-cinemas-beekman-theatre-new-york',
#   'telephone': '(212) 249-0807',
#   'website': None},
#  {'booking_type': None,
#   'chain_id': '269',
#   'id': '56432',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '18 W. Houston St., at Mercer St., New York, NY, 10012',
#     'house': '18',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'West Houston Street',
#     'zipcode': None},
#    'lat': 37.09024,
#    'lon': -95.712891},
#   'name': 'Angelika Film Center New York',
#   'slug': 'angelika-film-center-new-york',
#   'telephone': '(212) 995-2570',
#   'website': None},
#  {'booking_type': 'external',
#   'chain_id': '27',
#   'id': '56487',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '247 W 42nd St New York, NY',
#     'house': '247',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'W 42nd St',
#     'zipcode': None},
#    'lat': 37.09024,
#    'lon': -95.712891},
#   'name': 'Regal E-Walk Stadium 13 & RPX',
#   'slug': 'regal-e-walk-stadium-13-rpx',
#   'telephone': '(844) 462-7342 ext 775',
#   'website': 'http://www.regmovies.com/theaters/regal-e-walk-stadium-13-rpx/10131'},
#  {'booking_type': 'external',
#   'chain_id': '79',
#   'id': '56492',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '260 west 23rd street, new york, new york',
#     'house': '260',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'West 23rd Street',
#     'zipcode': None},
#    'lat': 37.09024,
#    'lon': -95.712891},
#   'name': 'Cinépolis Chelsea',
#   'slug': 'bow-tie-chelsea-cinemas-new-york',
#   'telephone': '(212) 691-5519',
#   'website': 'http://www.cinepolisusa.com/locations/chelsea'},
#  {'booking_type': 'external',
#   'chain_id': '33',
#   'id': '58056',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '625 West 57th Street, at 12th Avenue, New York, NY, 10019',
#     'house': '625',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'West 57th Street',
#     'zipcode': '10019'},
#    'lat': 40.7714779,
#    'lon': -73.9930129},
#   'name': 'The Landmark at 57 West',
#   'slug': 'the-landmark-at-57-west-new-york',
#   'telephone': None,
#   'website': None},
#  {'booking_type': None,
#   'chain_id': '270',
#   'id': '60749',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '2 & 3, 1001 3rd Ave., @ 60th St., New York, NY, 10065',
#     'house': '1001',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': '3rd Avenue',
#     'zipcode': '10022'},
#    'lat': 40.7618628,
#    'lon': -73.9660855},
#   'name': 'Cinemas 1, 2 & 3',
#   'slug': 'cinemas-1-2-3-new-york',
#   'telephone': '(212) 753-6022',
#   'website': None},
#  {'booking_type': None,
#   'chain_id': '270',
#   'id': '60750',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '4 W. 58th St., @ 5th Ave., New York, NY, 10019',
#     'house': None,
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'West 58th Street',
#     'zipcode': '10022'},
#    'lat': 40.7636484,
#    'lon': -73.9734618},
#   'name': 'The Paris Theatre',
#   'slug': 'the-paris-theatre-new-york',
#   'telephone': '(212) 823-8945',
#   'website': None},
#  {'booking_type': 'external',
#   'chain_id': '322',
#   'id': '61470',
#   'location': {'address': {'city': 'New York',
#     'country': 'United States',
#     'country_code': 'US',
#     'display_text': '11 Fulton St, New York, NY 10038',
#     'house': '180',
#     'state': 'New York',
#     'state_abbr': 'NY',
#     'street': 'Water Street',
#     'zipcode': '10038'},
#    'lat': 40.7067,
#    'lon': -74.0054},
#   'name': 'iPic Fulton Market',
#   'slug': 'ipic-fulton-market-new-york',
#   'telephone': '212-776-8272',
#   'website': None}]

# %%
# ishowtimes_url = "https://api.internationalshowtimes.com/v4/cinemas"
# parameters = {'country': 'US'}
# headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}

# UScinemas = (requests.get(ishowtimes_url, params=parameters, headers=headers).json())['cinemas']

# NYCcinemas = []

# for cinema in UScinemas:
#     if cinema['location']['address']['city'] == 'New York':
#         NYCcinemas.append(cinema)
        
# df2 = pd.DataFrame(NYCcinemas)
# df2

# %%
for cinema in NYCcinemas:
    if cinema['location']['address']['zipcode'] == '10034':
        print(cinema['name'])

# %% [markdown]
# #### Get all movie ids of 16 important genres
# No genre 9: there are no movies under the genre "History" (genre id 9) out right now, so we left it out to avoid the errors it was causing.  Realistically, since movies are typically listed as multiple genres, any movie in the future classified as History will likely be also captured by another genre here and represented in our program (e.g. a Historical Drama, Documentary, War, etc.)

# %%
genres = [
    {"id": "0", "title": "Action"},
    {"id": "1", "title": "Adventure"},
    {"id": "2", "title": "Animation"},
    {"id": "3", "title": "Comedy"},
    {"id": "4", "title": "Crime"},
    {"id": "5", "title": "Documentary"},
    {"id": "6", "title": "Drama"},
    {"id": "7", "title": "Family"},
    {"id": "8", "title": "Foreign"},
    {"id": "10", "title": "Horror"},
    {"id": "11", "title": "Mystery"},
    {"id": "12", "title": "Romance"},
    {"id": "13", "title": "Science Fiction"},
    {"id": "14", "title": "Thriller"},
    {"id": "15", "title": "War"},
    {"id": "16", "title": "Western"}
]

genres_ids = []

# %% [markdown]
# Next we have to call the ishowtimes API to access the movies by genre.  Unfortunately, because of the way the iShowtimes API is set up, we have to run separate calls for each genre which makes the program run rather slowly.  If you call the API and request all movies in a certain country or city, the results do not include the movie's genre and thus we couldn't simply make one call to gather the movies before sorting by genre.

# %%
# Genre 0
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '0'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre0 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre0_ids = [movie['id'] for movie in genre0]
genres_ids.append(genre0_ids)

# %%
# Genre 1
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US', 'genre_ids': '1'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre1 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre1_ids = [movie['id'] for movie in genre1]
genres_ids.append(genre1_ids)

# %%
# Genre 2
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '2'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre2 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre2_ids = [movie['id'] for movie in genre2]
genres_ids.append(genre2_ids)

# %%
# Genre 3
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '3'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre3 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre3_ids = [movie['id'] for movie in genre3]
genres_ids.append(genre3_ids)

# %%
# Genre 4
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '4'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre4 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre4_ids = [movie['id'] for movie in genre4]
genres_ids.append(genre4_ids)

# %%
# Genre 5
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '5'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre5 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre5_ids = [movie['id'] for movie in genre5]
genres_ids.append(genre5_ids)

# %%
# Genre 6
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '6'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre6 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre6_ids = [movie['id'] for movie in genre6]
genres_ids.append(genre6_ids)

# %%
# Genre 7
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '7'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre7 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre7_ids = [movie['id'] for movie in genre7]
genres_ids.append(genre7_ids)

# %%
# Genre 8
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '8'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre8 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre8_ids = [movie['id'] for movie in genre8]
genres_ids.append(genre8_ids)

# %%
# Genre 10
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '10'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre10 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre10_ids = [movie['id'] for movie in genre10]
genres_ids.append(genre10_ids)

# %%
# Genre 11
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '11'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre11 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre11_ids = [movie['id'] for movie in genre11]
genres_ids.append(genre11_ids)

# %%
# Genre 12
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '12'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre12 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre12_ids = [movie['id'] for movie in genre12]
genres_ids.append(genre12_ids)

# %%
# Genre 13
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '13'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre13 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre13_ids = [movie['id'] for movie in genre13]
genres_ids.append(genre13_ids)

# %%
# Genre 14
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '14'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre14 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre14_ids = [movie['id'] for movie in genre14]
genres_ids.append(genre14_ids)

# %%
# Genre 15
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '15'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre15 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre15_ids = [movie['id'] for movie in genre15]
genres_ids.append(genre15_ids)

# %%
# Genre 16
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US','genre_ids': '16'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
genre16 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']

genre16_ids = [movie['id'] for movie in genre16]
genres_ids.append(genre16_ids)

# %% [markdown]
# #### Get all movie information

# %%
ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
parameters = {'country': 'US'}
headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
movies_ids_titles = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
movies_ids_titles
# Out:
# [{'id': '30767',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg',
#   'slug': 'avengers-infinity-war',
#   'title': 'Avengers: Infinity War'},
#  {'id': '27220',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zWoFYfjEArXKjTJX6akSveGYSs3.jpg',
#   'slug': 'deadpool-2',
#   'title': 'Deadpool 2'},
#  {'id': '31829',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4oD6VEccFkorEBTEDXtpLAaz0Rl.jpg',
#   'slug': 'han-solo-a-star-wars-story',
#   'title': 'Solo: A Star Wars Story'},
#  {'id': '31465',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/A2S4p7mRt0iyClSLSldfjzdYSIp.jpg',
#   'slug': 'life-of-the-party',
#   'title': 'Life of the Party'},
#  {'id': '30227',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mrepRTUhNKU70PFf7LNQypbkH00.jpg',
#   'slug': 'a-quiet-place',
#   'title': 'A Quiet Place'},
#  {'id': '40796',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bKH7H4f5LPBQ5KOmHPcYtxCo7Od.jpg',
#   'slug': 'breaking-in',
#   'title': 'Breaking In'},
#  {'id': '33658',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bZe6x2fKtwVDsAvZQ9fnIJznBrc.jpg',
#   'slug': 'i-feel-pretty',
#   'title': 'I Feel Pretty'},
#  {'id': '30509',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/30oXQKwibh0uANGMs0Sytw3uN22.jpg',
#   'slug': 'rampage-043343be-385f-420f-988e-64b4aaf9d18e',
#   'title': 'Rampage'},
#  {'id': '35361',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/gaHknuun1VPPugkTsSfB8PejKVg.jpg',
#   'slug': 'overboard-a645942f-a72d-42e3-aaa4-83a661b682a2',
#   'title': 'Overboard'},
#  {'id': '31236',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zWoIgYCAJlXMWp7VxNLK0AVYvSR.jpg',
#   'slug': 'tully',
#   'title': 'Tully'},
#  {'id': '38750',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zbvziwnZa91AJD78Si0hUb5JP5X.jpg',
#   'slug': 'truth-or-dare-6045fd52-646e-4929-bb67-e9f74eb5e383',
#   'title': 'Truth or Dare'},
#  {'id': '27235',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xHdf2wRgCSp9MrZRryikiZIH6jB.jpg',
#   'slug': 'gnomeo-juliet-sherlock-gnomes',
#   'title': 'Sherlock Gnomes'},
#  {'id': '32282',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/c9XxwwhPHdaImA2f1WEfEsbhaFB.jpg',
#   'slug': 'jurassic-world-ii',
#   'title': 'Jurassic World: Fallen Kingdom'},
#  {'id': '12222',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/uxzzxijgPIY7slzFvMotPv8wjKA.jpg',
#   'slug': 'black-panther',
#   'title': 'Black Panther'},
#  {'id': '42510',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ojCu9SLxAPwhhC2tXtHNdrTmxCH.jpg',
#   'slug': 'bad-samaritan',
#   'title': 'Bad Samaritan'},
#  {'id': '23887',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/yAcb58vipewa1BfNit2RjE6boXA.jpg',
#   'slug': 'a-wrinkle-in-time',
#   'title': 'A Wrinkle in Time'},
#  {'id': '41921',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cx0LpfM6Drla8uzFfMT09uqKPRu.jpg',
#   'slug': 'blockers',
#   'title': 'Blockers'},
#  {'id': '26624',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/c0nUX6Q1ZB0P2t1Jo6EeFSVnOGQ.jpg',
#   'slug': 'isle-of-dogs',
#   'title': 'Isle of Dogs'},
#  {'id': '34626',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/81Kumk0nbZAVqRMo3Zwq00IlgRa.jpg',
#   'slug': 'super-troopers-2',
#   'title': 'Super Troopers 2'},
#  {'id': '29666',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/pU1ULUq8D3iRxl1fdX2lZIzdHuI.jpg',
#   'slug': 'ready-player-one',
#   'title': 'Ready Player One'},
#  {'id': '29483',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/2yjSvEDuM3rLDng40erLsWkQRfn.jpg',
#   'slug': 'peter-rabbit',
#   'title': 'Peter Rabbit'},
#  {'id': '39501',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qjuQQy9cZxztIiIB3gNIjImaiwB.jpg',
#   'slug': 'raazi',
#   'title': 'Raazi'},
#  {'id': '32390',
#   'poster_image_thumbnail': None,
#   'slug': '102-not-out',
#   'title': '102 Not Out'},
#  {'id': '45121',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zHGf3PWSqwt3X1UEIO2ythLwvKO.jpg',
#   'slug': 'book-club-352459',
#   'title': 'Book Club'},
#  {'id': '38014',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cuQIr6nn5r5sjsYSvpgbugPOqQ.jpg',
#   'slug': 'guernsey',
#   'title': 'The Guernsey Literary and Potato Peel Pie Society'},
#  {'id': '35062',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ubSpsYP3WqljVPVSX2FbBNYZoR1.jpg',
#   'slug': 'traffik',
#   'title': 'Traffik'},
#  {'id': '21112',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/sj9Vjp8vDflQulgst4Xg6qWxLAd.jpg',
#   'slug': 'untitled-asghar-farhadi-project',
#   'title': 'Everybody Knows'},
#  {'id': '39075',
#   'poster_image_thumbnail': None,
#   'slug': 'rapurasu-no-majo',
#   'title': "Laplace's Witch"},
#  {'id': '35369',
#   'poster_image_thumbnail': None,
#   'slug': '511c51c8-c6e6-444f-8850-9fcbf5cfd6d3',
#   'title': 'The Blood of Wolves'},
#  {'id': '43496',
#   'poster_image_thumbnail': None,
#   'slug': 'monsieur-je-sais-tout',
#   'title': None},
#  {'id': '43168',
#   'poster_image_thumbnail': None,
#   'slug': 'liliane-susewind-ein-tierisches-abenteuer',
#   'title': None},
#  {'id': '34566',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/c7iefOekZrKT543uhNqbjtZc7gc.jpg',
#   'slug': 'i-can-only-imagine',
#   'title': 'I Can Only Imagine'},
#  {'id': '35474',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/eHUYOblevtR82bCYnAgS1qSNdea.jpg',
#   'slug': 'chappaquiddick',
#   'title': 'Chappaquiddick'},
#  {'id': '41175',
#   'poster_image_thumbnail': None,
#   'slug': 'abdel-et-la-comtesse',
#   'title': None},
#  {'id': '26525',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zRpOwIlOXZZVWgDernbPbdHU5cl.jpg',
#   'slug': 'death-wish',
#   'title': 'Death Wish'},
#  {'id': '42740',
#   'poster_image_thumbnail': None,
#   'slug': '64469720-e504-41bd-91e1-8c2cf784ae4d',
#   'title': 'My Little Monster'},
#  {'id': '28406',
#   'poster_image_thumbnail': None,
#   'slug': 'taxi-5',
#   'title': 'Taxi 5'},
#  {'id': '29368',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/i8pjBv8LGN0SiAYGFQGld5HkR6Y.jpg',
#   'slug': 'game-night',
#   'title': 'Game Night'},
#  {'id': '33237',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/9QA8rjbMqPcJXdHWEZE4Nxvktgx.jpg',
#   'slug': 'tyler-perry-s-she-s-living-my-life',
#   'title': 'Acrimony'},
#  {'id': '30722',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/F7iwejv5IjialAINO1mwRfTeUw.jpg',
#   'slug': 'entebbe',
#   'title': '7 Days in Entebbe'},
#  {'id': '40233',
#   'poster_image_thumbnail': None,
#   'slug': 'ee7b0aaf-2cb4-4ffa-8a04-b9898bab8f0e',
#   'title': 'Inuyashiki'},
#  {'id': '39802',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vcF5gDPdBVmtPsFP3MMIlHm4moG.jpg',
#   'slug': 'rbg',
#   'title': 'RBG'},
#  {'id': '20738',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/2iRQD18mRCYJ6hfzxd8hoMD7OSS.jpg',
#   'slug': 'breath',
#   'title': 'Breath'},
#  {'id': '27713',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ugw07fJIZMVrrIGeN1MO7Xecj5h.jpg',
#   'slug': 'early-man',
#   'title': 'Early Man'},
#  {'id': '26665',
#   'poster_image_thumbnail': None,
#   'slug': 'jim-knopf-und-lukas-der-lokomotivfuhrer',
#   'title': 'Jim Knopf und Lukas der Lokomotivführer'},
#  {'id': '32146',
#   'poster_image_thumbnail': None,
#   'slug': 'mahanati',
#   'title': 'Mahanati'},
#  {'id': '31835',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zfuXFlzBHPmPMA8DU1apreayuoi.jpg',
#   'slug': 'mamma-mia-here-we-go-again',
#   'title': 'Mamma Mia: Here We Go Again!'},
#  {'id': '12252',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/dfhztJRiElqmYW4kpvjYe1gENsD.jpg',
#   'slug': 'the-greatest-showman-on-earth',
#   'title': 'The Greatest Showman'},
#  {'id': '39170',
#   'poster_image_thumbnail': None,
#   'slug': 'larguees',
#   'title': 'Dumped'},
#  {'id': '38269',
#   'poster_image_thumbnail': None,
#   'slug': 'la-place-publique',
#   'title': 'Place publique'},
#  {'id': '41173',
#   'poster_image_thumbnail': None,
#   'slug': 'les-municipaux-ces-heros',
#   'title': None},
#  {'id': '43286',
#   'poster_image_thumbnail': None,
#   'slug': 'plaire-aimer-et-courir-vite',
#   'title': 'Sorry Angel'},
#  {'id': '29383',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/j18021qCeRi3yUBtqd2UFj1c0RQ.jpg',
#   'slug': 'horse-soldiers',
#   'title': '12 Strong'},
#  {'id': '42698',
#   'poster_image_thumbnail': None,
#   'slug': '52b22dd3-46dd-44fc-b644-2f93f87b6f9f',
#   'title': 'Crayon Shin-chan: Burst Serving! Kung Fu Boys ~Ramen Rebellion~'},
#  {'id': '45339',
#   'poster_image_thumbnail': None,
#   'slug': '14840ec6-d339-4919-a21c-9067503d75bd',
#   'title': 'Marmalade Boy'},
#  {'id': '43540',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ghY4WbHSfyBrJ8snx7snqxLpuvz.jpg',
#   'slug': 'luis-and-the-aliens',
#   'title': 'Luis & the Aliens'},
#  {'id': '20561',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bXrZ5iHBEjH7WMidbUDQ0U2xbmr.jpg',
#   'slug': 'jumanji-1f7239e5-12d6-4075-8621-dab563f89ed3',
#   'title': 'Jumanji: Welcome to the Jungle'},
#  {'id': '12180',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/v5HlmJK9bdeHxN2QhaFP1ivjX3U.jpg',
#   'slug': 'pacific-rim-2',
#   'title': 'Pacific Rim: Uprising'},
#  {'id': '41174',
#   'poster_image_thumbnail': None,
#   'slug': 'amoureux-de-ma-femme',
#   'title': 'The Other Woman'},
#  {'id': '45399',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wo3gu56JKRwZ2TpKt8mPjXLQK23.jpg',
#   'slug': 'the-strangers-prey-at-night',
#   'title': 'The Strangers: Prey at Night'},
#  {'id': '26537',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xAKqG5SpsHU7vI6Fh4UYxFrDDZZ.jpg',
#   'slug': 'the-death-of-stalin',
#   'title': 'The Death of Stalin'},
#  {'id': '39775',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mMWV5MXn2pkDnnI4vWpy3dRWdNC.jpg',
#   'slug': '6a9728d5-03a6-4dd2-90cf-c3e81f076ca7',
#   'title': 'Detective Conan: Zero the Enforcer'},
#  {'id': '28321',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/AewyKG2cvgZQBG4XU6SVomfu1k5.jpg',
#   'slug': 'crooked-house',
#   'title': 'Crooked House'},
#  {'id': '28283',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ktPbjD6nYg5NxmeTt72Iqaw5GD0.jpg',
#   'slug': 'you-were-never-really-here',
#   'title': 'You Were Never Really Here'},
#  {'id': '35909',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bGsfNIvhnbGS75e2MXrti6dMzcy.jpg',
#   'slug': 'paul-apostle-of-christ',
#   'title': 'Paul, Apostle of Christ'},
#  {'id': '29308',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ePyN2nX9t8SOl70eRW47Q29zUFO.jpg',
#   'slug': 'tomb-raider',
#   'title': 'Tomb Raider'},
#  {'id': '41398',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/46zecZYX8rWeDlr5PosCd1bC1Up.jpg',
#   'slug': 'naa-peru-surya',
#   'title': 'Naa Peru Surya - Naa Illu India'},
#  {'id': '34219',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/iySFtKLrWvVzXzlFj7x1zalxi5G.jpg',
#   'slug': 'lady-bird',
#   'title': 'Lady Bird'},
#  {'id': '41171',
#   'poster_image_thumbnail': None,
#   'slug': 'campeones',
#   'title': None},
#  {'id': '24252',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cPsa2odqNRz4WJVd4f8yZWui3iu.jpg',
#   'slug': 'disobedience',
#   'title': 'Disobedience'},
#  {'id': '41177',
#   'poster_image_thumbnail': None,
#   'slug': 'milf',
#   'title': 'MILF'},
#  {'id': '32751',
#   'poster_image_thumbnail': None,
#   'slug': 'love-addict-01d349ec-eb83-4fbe-8e4b-3ac733315789',
#   'title': None},
#  {'id': '28141',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7SuPHSo9Uw8GACkP2oPst512Qhl.jpg',
#   'slug': 'lean-on-pete',
#   'title': 'Lean on Pete'},
#  {'id': '39722',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/8pIRi67oPq91CnkRUwl9PWiYZKA.jpg',
#   'slug': 'the-miracle-season',
#   'title': 'The Miracle Season'},
#  {'id': '26529',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/dxeVPklFwng2IowqRPNI4od6aXv.jpg',
#   'slug': 'american-express',
#   'title': 'Gringo'},
#  {'id': '40215',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/jcEvwztUuVqYRNClf1ZpyRUKt4e.jpg',
#   'slug': '3-tage-in-quiberon',
#   'title': '3 Days in Quiberon'},
#  {'id': '39171',
#   'poster_image_thumbnail': None,
#   'slug': 'comme-des-rois',
#   'title': 'Comme des rois'},
#  {'id': '30155',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5YUYg5q7QfC4IoNwNUtiwdiYKPr.jpg',
#   'slug': 'simon-vs-the-homo-sapiens-agenda',
#   'title': 'Love, Simon'},
#  {'id': '44524',
#   'poster_image_thumbnail': None,
#   'slug': 'en-guerre',
#   'title': 'At War'},
#  {'id': '25286',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/6McYL1YZmRSeccDXxpFNslUw2c5.jpg',
#   'slug': 'escobar',
#   'title': 'Loving Pablo'},
#  {'id': '39022',
#   'poster_image_thumbnail': None,
#   'slug': 'das-schweigende-klassenzimmer',
#   'title': 'The Silent Revolution'},
#  {'id': '25586',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/eKi8dIrr8voobbaGzDpe8w0PVbC.jpg',
#   'slug': 'coco',
#   'title': 'Coco'},
#  {'id': '28872',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bMSDciBev8h9P6KvxnQDOnExg0j.jpg',
#   'slug': 'the-bookshop',
#   'title': 'The Bookshop'},
#  {'id': '30582',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/6pdyyYbgq8prtbr2kocllUHGbqS.jpg',
#   'slug': 'the-rider',
#   'title': 'The Rider'},
#  {'id': '26556',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xYWYsiTlCpnBF2rw2ie1XwKvxGO.jpg',
#   'slug': 'high-wire-act',
#   'title': 'Beirut'},
#  {'id': '24791',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/AchOrDSCMCAGiiY4QdBnNgvmWHq.jpg',
#   'slug': 'midnight-sun',
#   'title': 'Midnight Sun'},
#  {'id': '34256',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ziBy2wFxLI3sGBqbfu8VVtO8mdA.jpg',
#   'slug': 'den-utrolige-historie-om-den-kaempestore-paere',
#   'title': 'The Incredible Story of the Giant Pear'},
#  {'id': '29153',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qyRwj5VvuTRdJ76o2grP93grNxt.jpg',
#   'slug': 'the-post',
#   'title': 'The Post'},
#  {'id': '29786',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/avmWN1YGYbzW4n1cbffw4uLCZSr.jpg',
#   'slug': 'the-journey',
#   'title': 'The Journey'},
#  {'id': '25205',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/fyufzd2S1lLxMxkTHTnmr6VJfe5.jpg',
#   'slug': 'red-sparrow',
#   'title': 'Red Sparrow'},
#  {'id': '42909',
#   'poster_image_thumbnail': None,
#   'slug': 'nada-a-perder-contra-tudo-por-todos',
#   'title': 'Nada a Perder'},
#  {'id': '28842',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ec59rAksDZwMaOZl1DHOXNJxIfz.jpg',
#   'slug': 'foxtrot',
#   'title': 'Foxtrot'},
#  {'id': '40274',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vB7C72NL83j587lnq5gDizazsl.jpg',
#   'slug': 'transit-ca3c76cd-9f21-47f4-a70c-3d88f94460f0',
#   'title': 'Transit\xa0'},
#  {'id': '37952',
#   'poster_image_thumbnail': None,
#   'slug': '5669f762-e89b-475c-b5c7-c0c3f804c7eb',
#   'title': 'Chihayafuru Part III'},
#  {'id': '42689',
#   'poster_image_thumbnail': None,
#   'slug': 'la-ch-tite-famille',
#   'title': "La ch'tite famille"},
#  {'id': '6396',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/d8J98dLZkfTpJY64VvtCOH2UkXP.jpg',
#   'slug': 'porco-rosso',
#   'title': 'Porco Rosso'},
#  {'id': '45299',
#   'poster_image_thumbnail': None,
#   'slug': 'loro-2',
#   'title': 'Loro 2'},
#  {'id': '27519',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zpVqh11aATvy0fsAvEVhRNlkIhq.jpg',
#   'slug': 'yoake-tsugeru-lu-no-uta',
#   'title': 'Lu Over the Wall'},
#  {'id': '29922',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/h9hUP5ZJGsjL2wbERrGlj4dMjZq.jpg',
#   'slug': 'molly-s-game',
#   'title': "Molly's Game"},
#  {'id': '33921',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/jvDBfavZASdKsJunu9VCAtXjLS2.jpg',
#   'slug': 'unsane',
#   'title': 'Unsane'},
#  {'id': '30880',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/1MwoZ4U8SGm7yIzfPFcTTbiiOYY.jpg',
#   'slug': 'god-s-not-dead-3',
#   'title': "God's Not Dead: A Light in Darkness"},
#  {'id': '41255',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bpa91Opnvl4XxUCycyNGvhwRWqC.jpg',
#   'slug': 'utoya-22-juli',
#   'title': 'U: July 22'},
#  {'id': '38555',
#   'poster_image_thumbnail': None,
#   'slug': '34c3b1ac-dd1a-4045-9faa-64ff673c564e',
#   'title': 'Irumbu Thirai'},
#  {'id': '28803',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/gxMK7webO1uaoMWgGDfCqlbnLpr.jpg',
#   'slug': 'aurore',
#   'title': 'I Got Life!'},
#  {'id': '43150',
#   'poster_image_thumbnail': None,
#   'slug': 'herrliche-zeiten',
#   'title': 'HERRliche Zeiten'},
#  {'id': '41333',
#   'poster_image_thumbnail': None,
#   'slug': 'andre-rieu-s-maastricht-konzert-2018',
#   'title': None},
#  {'id': '35468',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/6gNXwSHxaksR1PjVZRqNapmkgj3.jpg',
#   'slug': 'i-tonya',
#   'title': 'I, Tonya'},
#  {'id': '41772',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/yVmvBOv1E5i6XUnQaThKt5x3FbQ.jpg',
#   'slug': 'the-breaker-upperers',
#   'title': 'The Breaker Upperers'},
#  {'id': '32518',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qvLvMOpZkMps0JCuNrRIXBX7h4p.jpg',
#   'slug': 'the-leisure-seeker',
#   'title': 'The Leisure Seeker'},
#  {'id': '21156',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xhBTO9n3fxy3HJt7WlR9h9vvVmk.jpg',
#   'slug': 'anon',
#   'title': 'Anon'},
#  {'id': '45498',
#   'poster_image_thumbnail': None,
#   'slug': 'daana-paani',
#   'title': 'Daana Paani'},
#  {'id': '12163',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/9MsQJKe4cUAGxc7R2NGaFQLqOPc.jpg',
#   'slug': 'boss-baby',
#   'title': 'The Boss Baby'},
#  {'id': '31945',
#   'poster_image_thumbnail': None,
#   'slug': 'comme-des-garcons',
#   'title': 'Let the Girls Play'},
#  {'id': '44975',
#   'poster_image_thumbnail': None,
#   'slug': 'only-the-brave',
#   'title': None},
#  {'id': '20747',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/nPTjj6ZfBXXBwOhd7iUy6tyuKWt.jpg',
#   'slug': 'call-me-by-your-name',
#   'title': 'Call Me by Your Name'},
#  {'id': '32663',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/hL9Uz2vq93vi20oxZEBBaSs4w8U.jpg',
#   'slug': 'the-incredibles-2',
#   'title': 'Incredibles 2'},
#  {'id': '42314',
#   'poster_image_thumbnail': None,
#   'slug': 'la-bolduc',
#   'title': 'La Bolduc'},
#  {'id': '45577',
#   'poster_image_thumbnail': None,
#   'slug': 'tonno-spiaggiato',
#   'title': None},
#  {'id': '45303',
#   'poster_image_thumbnail': None,
#   'slug': 'deadpool-s-double-feature',
#   'title': None},
#  {'id': '37162',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7yj6Gqca7DxwNp6qZefsHNFpg6U.jpg',
#   'slug': 'e78e4621-bbb6-4541-9b45-e72479755531',
#   'title': 'Liz and the Blue Bird'},
#  {'id': '12171',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4VmZeT8YkuMI6BrA623mHZDISlN.jpg',
#   'slug': 'hitman-agent-47',
#   'title': 'Hitman: Agent 47'},
#  {'id': '26499',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/tA1mXJF75y57MvsZv2gDhbi0B4x.jpg',
#   'slug': 'kings',
#   'title': 'Kings'},
#  {'id': '34308',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/3aUuot6sJCQqk1bK4UYPs8omMId.jpg',
#   'slug': 'hva-vil-folk-si',
#   'title': 'What Will People Say'},
#  {'id': '30255',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/taS8PKlS684NkYrEMnIBS59pDu5.jpg',
#   'slug': 'sgt-stubby-an-american-hero-tm',
#   'title': 'Sgt. Stubby: An American Hero'},
#  {'id': '20851',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vgvw6w1CtcFkuXXn004S5wQsHRl.jpg',
#   'slug': 'three-billboards-outside-ebbing-missouri',
#   'title': 'Three Billboards Outside Ebbing, Missouri'},
#  {'id': '41922',
#   'poster_image_thumbnail': None,
#   'slug': 'who-owns-nature',
#   'title': None},
#  {'id': '41667',
#   'poster_image_thumbnail': None,
#   'slug': 'bharat-ane-nenu',
#   'title': 'Bharat Ane Nenu'},
#  {'id': '28368',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/kZdncyp1IKhEqwv5zdmUpK5Dc7S.jpg',
#   'slug': 'beast-83f900d6-5b7e-4030-a7db-0c6b9501af48',
#   'title': 'Beast'},
#  {'id': '45185',
#   'poster_image_thumbnail': None,
#   'slug': 'arrivano-i-prof',
#   'title': 'Arrivano i prof'},
#  {'id': '44194',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/jDbo0q93fPKsfU9LkJQ38ZaD03r.jpg',
#   'slug': 'indian-horse',
#   'title': 'Indian Horse'},
#  {'id': '32679',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/iilu7fMIXPTuirk4mCN7eNifBhn.jpg',
#   'slug': 'finding-your-feet',
#   'title': 'Finding Your Feet'},
#  {'id': '25157',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7XURM64DYa9DpS70I2rM4suvq1s.jpg',
#   'slug': 'duck-duck-goose',
#   'title': 'Duck Duck Goose'},
#  {'id': '45484',
#   'poster_image_thumbnail': None,
#   'slug': '7434227b-ce17-49ac-a34f-a79c09930505',
#   'title': 'A or B'},
#  {'id': '26532',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/2TDroy5YKKCthnXnAERjjGnusKw.jpg',
#   'slug': 'stronger',
#   'title': 'Stronger'},
#  {'id': '31640',
#   'poster_image_thumbnail': None,
#   'slug': 'le-fidele',
#   'title': 'Racer and the Jailbird'},
#  {'id': '40557',
#   'poster_image_thumbnail': None,
#   'slug': 'an-american-in-paris-a-new-musical',
#   'title': None},
#  {'id': '27050',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/hCDMgosnSnCSZejP1rDr5IFbQmV.jpg',
#   'slug': 'des-lunettes-noires',
#   'title': 'Let the Sunshine In'},
#  {'id': '26602',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/3Hv0jeuhQzz1tSjYwiLDHAMtDOl.jpg',
#   'slug': 'ghost-stories',
#   'title': 'Ghost Stories'},
#  {'id': '28959',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mQPujyTaD4F8P9NQZwls6gYjR3L.jpg',
#   'slug': '3a76ab55-9b26-4d4f-b41d-b7c1542032fc',
#   'title': "Mary and the Witch's Flower"},
#  {'id': '44506',
#   'poster_image_thumbnail': None,
#   'slug': 'mi-querida-cofradia',
#   'title': None},
#  {'id': '23458',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xa6G3aKlysQeVg9wOb0dRcIGlWu.jpg',
#   'slug': 'darkest-hour',
#   'title': 'Darkest Hour'},
#  {'id': '16435',
#   'poster_image_thumbnail': None,
#   'slug': 'the-sound-of-music',
#   'title': 'The Sound of Music'},
#  {'id': '21385',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/k4FwHlMhuRR5BISY2Gm2QZHlH5Q.jpg',
#   'slug': 'the-shape-of-water',
#   'title': 'The Shape of Water'},
#  {'id': '34213',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/hzeJtLmBpbUghACbJw4rFaDwzfs.jpg',
#   'slug': 'revenge',
#   'title': 'Revenge'},
#  {'id': '43290',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4hN08816wzk4JjH1sHOqrXJW2TA.jpg',
#   'slug': 'measure-of-a-man',
#   'title': 'Measure of a Man'},
#  {'id': '12089',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/z2sJd1OvAGZLxgjBdSnQoLCfn3M.jpg',
#   'slug': 'mission-impossible-5',
#   'title': 'Mission: Impossible - Rogue Nation'},
#  {'id': '21221',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/rclxSjQ85P5c1W1esvgXlpql36R.jpg',
#   'slug': 'terminal',
#   'title': 'Terminal'},
#  {'id': '44800',
#   'poster_image_thumbnail': None,
#   'slug': 'gueule-d-ange',
#   'title': 'Angel Face'},
#  {'id': '35485',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/g5ovAJCK1oXOSqa84Soj3Mj21jB.jpg',
#   'slug': '55-steps',
#   'title': '55 Steps'},
#  {'id': '42905',
#   'poster_image_thumbnail': None,
#   'slug': 'd6880546-5f52-464c-b120-8aa272b6690e',
#   'title': "Doraemon the Movie: Nobita's Treasure Island"},
#  {'id': '30532',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ltWxsC5S0v1uyOX46qcQm1N7VZf.jpg',
#   'slug': 'le-redoutable',
#   'title': 'Godard Mon Amour'},
#  {'id': '33798',
#   'poster_image_thumbnail': None,
#   'slug': 'bhaskar-oru-rascal',
#   'title': 'Bhaskar Oru Rascal'},
#  {'id': '15753',
#   'poster_image_thumbnail': None,
#   'slug': 'the-importance-of-being-earnest-oscar-wilde-play',
#   'title': None},
#  {'id': '41176',
#   'poster_image_thumbnail': None,
#   'slug': 'cornelius-le-meunier-hurlant',
#   'title': None},
#  {'id': '45288',
#   'poster_image_thumbnail': None,
#   'slug': 'muse-drones-world-tour',
#   'title': 'Muse: Drones World Tour'},
#  {'id': '30521',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7WtFoWtGp45PLNmajM8iGtjAA7B.jpg',
#   'slug': 'tadeo-jones-2-el-secreto-del-rey-midas',
#   'title': 'Tad the Lost Explorer and the Secret of King Midas'},
#  {'id': '35360',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wq3IH5m4gOsbMUdyXOKVbwOZuzE.jpg',
#   'slug': '5b696950-9e2a-4cc8-bf8f-8d6098e99960',
#   'title': 'Kammara Sambhavam'},
#  {'id': '21244',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wLu2N0QVfSpk10RJ17HLHyRUmww.jpg',
#   'slug': 'breathe',
#   'title': 'Breathe'},
#  {'id': '43460',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/47YDdPKM5qmuOWjxwOcQJtobpqa.jpg',
#   'slug': 'omerta',
#   'title': 'Omertà'},
#  {'id': '36548',
#   'poster_image_thumbnail': None,
#   'slug': 'luna-92b7f7fa-4d85-4481-b2fd-da8978d47054',
#   'title': 'Luna'},
#  {'id': '26598',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/myFTOsVDxu5sAWcw8hr0LlxBLnq.jpg',
#   'slug': 'loveless',
#   'title': 'Loveless'},
#  {'id': '33743',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/8e5IGlLrVjwrlDcRtzSQkXhJFWl.jpg',
#   'slug': 'roman-israel-esq',
#   'title': 'Roman J. Israel, Esq.'},
#  {'id': '45516',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/lmcVWX6PXHqopw1Umbl7m0VBrYz.jpg',
#   'slug': 'midnight-oil-1984',
#   'title': 'Midnight Oil: 1984'},
#  {'id': '45631',
#   'poster_image_thumbnail': None,
#   'slug': '10ede7de-16fb-4dfd-9d93-81367d28a147',
#   'title': 'I Am Your Mom'},
#  {'id': '27317',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/jNKHZ5BWYTdUtfdHv4WAVoCWcxP.jpg',
#   'slug': 'untitled-hirokazu-kore-eda-film',
#   'title': 'The Third Murder'},
#  {'id': '37992',
#   'poster_image_thumbnail': None,
#   'slug': 'funf-freunde-im-tal-der-dinosaurier',
#   'title': 'Fünf Freunde - Im Tal der Dinosaurier'},
#  {'id': '20572',
#   'poster_image_thumbnail': None,
#   'slug': 'katie-says-goodbye',
#   'title': 'Katie Says Goodbye'},
#  {'id': '35460',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/lWETGfd6FEHGecnKE6JuWeXy90c.jpg',
#   'slug': 'the-escape-07475d75-efff-4345-bc83-30a6c3bfaef2',
#   'title': 'The Escape'},
#  {'id': '33323',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wUt2efBP0Ar8PR7WyakSA2azX0w.jpg',
#   'slug': 'earth-one-amazing-day',
#   'title': 'Earth: One Amazing Day'},
#  {'id': '44832',
#   'poster_image_thumbnail': None,
#   'slug': 'mamma-mia-sing-along-version',
#   'title': None},
#  {'id': '44409',
#   'poster_image_thumbnail': None,
#   'slug': 'familiye',
#   'title': None},
#  {'id': '41035',
#   'poster_image_thumbnail': None,
#   'slug': '50a033a1-8d8a-4c01-bfd1-a0d4bb1d415e',
#   'title': 'Call Boy'},
#  {'id': '34210',
#   'poster_image_thumbnail': None,
#   'slug': 'gaston-lagaffe',
#   'title': 'Gaston Lagaffe'},
#  {'id': '37242',
#   'poster_image_thumbnail': None,
#   'slug': 'oxygen',
#   'title': 'Oxygen'},
#  {'id': '44200',
#   'poster_image_thumbnail': None,
#   'slug': 'ruth',
#   'title': 'Ruth'},
#  {'id': '34793',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vM0n8B8CULT0zxljdDRi1KuCYc8.jpg',
#   'slug': 'journeyman',
#   'title': 'Journeyman'},
#  {'id': '41945',
#   'poster_image_thumbnail': None,
#   'slug': 'c-est-quoi-cette-famille-338813',
#   'title': None},
#  {'id': '25170',
#   'poster_image_thumbnail': None,
#   'slug': 'sanky-panky-3',
#   'title': 'Sanky Panky 3'},
#  {'id': '32673',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mrRMYAzYfRZCeFJl92b4ZCCkRUU.jpg',
#   'slug': 'tri-5',
#   'title': 'Digimon Adventure Tri. - Chapter 5: Coexistence'},
#  {'id': '32515',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cCBB6BGRj5nCTaEgogDtkHfjOLK.jpg',
#   'slug': 'd1797722-7c39-415c-84fe-70d34314c16d',
#   'title': 'No Game No Life: Zero'},
#  {'id': '20982',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/a3IHgSwO5jWPLcGjKqbQ7pxVGkq.jpg',
#   'slug': 'suburbicon',
#   'title': 'Suburbicon'},
#  {'id': '36745',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/uGTvMD7u2ZSgbnaqbstIbn2XD9.jpg',
#   'slug': 'maria-by-callas',
#   'title': 'María by Callas'},
#  {'id': '7424',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7Z5hfRmasEUeypPczBjW92GzMgb.jpg',
#   'slug': 'daphne',
#   'title': 'Daphne'},
#  {'id': '41538',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qTnmj3eR2gsLnA182JuJ6jMwciO.jpg',
#   'slug': 'gurrumul',
#   'title': 'Gurrumul'},
#  {'id': '8401',
#   'poster_image_thumbnail': None,
#   'slug': 'ferdinand-im-muell',
#   'title': None},
#  {'id': '39230',
#   'poster_image_thumbnail': None,
#   'slug': 'mes-provinciales',
#   'title': 'A Paris Education'},
#  {'id': '42920',
#   'poster_image_thumbnail': None,
#   'slug': 'das-etruskische-lacheln',
#   'title': None},
#  {'id': '29973',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/gHFOh7zkvjuroY8DhseVePPpsKs.jpg',
#   'slug': 'funny-cow',
#   'title': 'Funny Cow'},
#  {'id': '32428',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7caaqQjTkovwoZsEOPzgHvkzOWB.jpg',
#   'slug': 'ocean-s-eight',
#   'title': "Ocean's 8"},
#  {'id': '31850',
#   'poster_image_thumbnail': None,
#   'slug': 'tout-le-monde-debout',
#   'title': 'Rolling to You'},
#  {'id': '42358',
#   'poster_image_thumbnail': None,
#   'slug': 'broken-0159fb1a-5a16-4349-ab95-194a7df03e58',
#   'title': 'Broken'},
#  {'id': '42593',
#   'poster_image_thumbnail': None,
#   'slug': 'wer-hat-eigentlich-die-liebe-erfunden',
#   'title': None},
#  {'id': '32318',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4URg3uF4wI2kikL9CYgBRApEU6A.jpg',
#   'slug': 'that-good-night',
#   'title': 'That Good Night'},
#  {'id': '31300',
#   'poster_image_thumbnail': None,
#   'slug': 'croc-blanc',
#   'title': 'White Fang'},
#  {'id': '34726',
#   'poster_image_thumbnail': None,
#   'slug': 'zurka',
#   'title': 'The Party'},
#  {'id': '21211',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/57C8wLEoeJ9vVqZarsfx54YEWxS.jpg',
#   'slug': 'un-sac-de-billes',
#   'title': 'A Bag of Marbles'},
#  {'id': '42743',
#   'poster_image_thumbnail': None,
#   'slug': 'the-dam-busters-at-75-live-from-royal-albert-hall',
#   'title': 'The Dam Busters At 75 Live from Royal Albert Hall'},
#  {'id': '34064',
#   'poster_image_thumbnail': None,
#   'slug': 'angels-wear-white',
#   'title': 'Angels Wear White'},
#  {'id': '39881',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mQw8Er3lcE0mi7pRooZJAIZ5Oyw.jpg',
#   'slug': 'in-den-gangen',
#   'title': 'In the Aisles'},
#  {'id': '28393',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/hKhfTKxcSqj64RtNXHJwyFPUB2W.jpg',
#   'slug': '44aa6845-9122-40ea-917c-76d450b977b6',
#   'title': 'Sobibor'},
#  {'id': '40824',
#   'poster_image_thumbnail': None,
#   'slug': 'os-farofeiros',
#   'title': 'Os Farofeiros'},
#  {'id': '36649',
#   'poster_image_thumbnail': None,
#   'slug': 'fd8bf641-1a6a-4503-ba5b-1f1eced77899',
#   'title': 'Iruttu Araiyil Murattu Kuthu'},
#  {'id': '26504',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/hLmrNU3fheH2j8BYVw3gCfyKFek.jpg',
#   'slug': 'le-sens-de-la-fete',
#   'title': "C'est la vie!"},
#  {'id': '30882',
#   'poster_image_thumbnail': None,
#   'slug': 'dolphins',
#   'title': 'Dolphins'},
#  {'id': '40322',
#   'poster_image_thumbnail': None,
#   'slug': 'iravukku-aayiram-kangal',
#   'title': 'Iravukku Aayiram Kangal'},
#  {'id': '29051',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/fy2K8jqCV9rNC8fHx9muPJTNaqs.jpg',
#   'slug': 'lucky',
#   'title': 'Lucky'},
#  {'id': '34971',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/44x3kGB7GNlps4ofMSJWGhLnx3Q.jpg',
#   'slug': 'arthur-claire',
#   'title': 'Arthur & Claire'},
#  {'id': '40962',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/aBfeHekIIjC4mFlark5MWJWDyZn.jpg',
#   'slug': 'die-biene-maja-die-honigspiele',
#   'title': 'Maya the Bee: The Honey Games'},
#  {'id': '45404',
#   'poster_image_thumbnail': None,
#   'slug': 'bb409b3f-78c1-42b5-a84c-476cd76b76a7',
#   'title': 'The Trough'},
#  {'id': '42142',
#   'poster_image_thumbnail': None,
#   'slug': 'funf-freunde-und-das-tal-der-dinosaurier',
#   'title': None},
#  {'id': '28417',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/3KgvDj7ldpRL8IPIlLM1cne01Wo.jpg',
#   'slug': 'knock',
#   'title': 'Knock'},
#  {'id': '28407',
#   'poster_image_thumbnail': None,
#   'slug': 'die-kleine-hexe-26e826e7-c33b-485f-a8c9-216ba461d83e',
#   'title': 'The Little Witch'},
#  {'id': '36148',
#   'poster_image_thumbnail': None,
#   'slug': 'deutschland-deutschland',
#   'title': 'Bye Bye Germany'},
#  {'id': '31009',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/6stbYJynPLfXfe4kNLUNk9mcoD.jpg',
#   'slug': 'the-son-of-bigfoot',
#   'title': 'The Son of Bigfoot'},
#  {'id': '42131',
#   'poster_image_thumbnail': None,
#   'slug': 'system-error',
#   'title': None},
#  {'id': '26562',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/7Rm5ZSyqJkC2PSWUI42xVzm3BT8.jpg',
#   'slug': 'on-chesil-beach',
#   'title': 'On Chesil Beach'},
#  {'id': '25258',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5LLxjWWQUW77TAeiCPW7ZpXLAec.jpg',
#   'slug': 'show-dogs',
#   'title': 'Show Dogs'},
#  {'id': '36103',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/hyjuYWtvLSTIUnQNlddXobfJNUN.jpg',
#   'slug': 'charmoren',
#   'title': 'The Charmer'},
#  {'id': '42134',
#   'poster_image_thumbnail': None,
#   'slug': 'mittelreich',
#   'title': None},
#  {'id': '45248',
#   'poster_image_thumbnail': None,
#   'slug': 'si-muore-tutti-democristiani',
#   'title': None},
#  {'id': '23812',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/lC7WdUNLOJI3sllaDGNdFy2GT8g.jpg',
#   'slug': 'granite-mountain',
#   'title': 'Only the Brave'},
#  {'id': '26273',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/gvW0Ki7pEv4iZYbtGwgcvqR6s1c.jpg',
#   'slug': 'the-sense-of-an-ending',
#   'title': 'The Sense of an Ending'},
#  {'id': '42666',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mKTenQeLVIHSiZ1b0wfsE44xPyD.jpg',
#   'slug': 'little-pink-house',
#   'title': 'Little Pink House'},
#  {'id': '33646',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ch2SDxd53QeBYk2y2QIl5E6Zn8o.jpg',
#   'slug': 'mohanlal',
#   'title': 'Mohanlal'},
#  {'id': '34000',
#   'poster_image_thumbnail': None,
#   'slug': 'aami',
#   'title': 'Aami'},
#  {'id': '12718',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/i8gEHh2sszB6YWLC0jl559sxAeN.jpg',
#   'slug': 'clueless-was-sonst',
#   'title': 'Clueless'},
#  {'id': '38267',
#   'poster_image_thumbnail': None,
#   'slug': 'la-fete-des-meres',
#   'title': None},
#  {'id': '37042',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/hkopJitcpOhQLy2nPfXUyGBH1M.jpg',
#   'slug': 'tri-chapter-6',
#   'title': 'Digimon Adventure Tri. - Chapter 6: Our Future'},
#  {'id': '42202',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/lH1QleR9NzzVouL4gp76CRnu9I6.jpg',
#   'slug': 'pope-francis-a-man-of-his-word',
#   'title': 'Pope Francis: A Man of His Word'},
#  {'id': '40960',
#   'poster_image_thumbnail': None,
#   'slug': 'la-priere',
#   'title': 'The Prayer'},
#  {'id': '30303',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wa4eAo4eCJ1S0i5JrZ1Z74L2LEC.jpg',
#   'slug': 'jeune-femme',
#   'title': 'Montparnasse Bienvenüe'},
#  {'id': '40550',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/nHUBPUwXkHinq2rIXnnCHsPylD1.jpg',
#   'slug': 'october',
#   'title': 'October'},
#  {'id': '28960',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5eyPpqvkH6OsXpohfHPk2FM8MVu.jpg',
#   'slug': 'mary-magdalene',
#   'title': 'Mary Magdalene'},
#  {'id': '28138',
#   'poster_image_thumbnail': None,
#   'slug': 'verdwijnen',
#   'title': 'Disappearance'},
#  {'id': '20930',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cqysALwxcE2C0OQJnsM8xdIWJ8T.jpg',
#   'slug': 'human-people',
#   'title': 'Person to Person'},
#  {'id': '24257',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bnSTP1PY2fDyat0eUa4QouuGV7F.jpg',
#   'slug': 'the-florida-project',
#   'title': 'The Florida Project'},
#  {'id': '37067',
#   'poster_image_thumbnail': None,
#   'slug': 'wildes-herz',
#   'title': None},
#  {'id': '8158',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cMtdpB65vRUo9Ge1hpmXFDWyJ8J.jpg',
#   'slug': 'boulevard-der-daemmerung',
#   'title': 'Sunset Boulevard'},
#  {'id': '24315',
#   'poster_image_thumbnail': None,
#   'slug': 'waiting-for-godik',
#   'title': None},
#  {'id': '40657',
#   'poster_image_thumbnail': None,
#   'slug': 'papa-moll',
#   'title': 'Mr. Moll and the Chocolate Factory'},
#  {'id': '40953',
#   'poster_image_thumbnail': None,
#   'slug': 'eldorado-319d2942-b3c6-4722-9259-2399c99cee52',
#   'title': 'Eldorado'},
#  {'id': '26561',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/pizynKUzJ9YucGff1O1MYisY1WM.jpg',
#   'slug': 'last-flag-flying',
#   'title': 'Last Flag Flying'},
#  {'id': '37847',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5OIGvfuJyVGtGMxZbdzMBYStHKS.jpg',
#   'slug': 'los-adioses',
#   'title': 'The Eternal Feminine'},
#  {'id': '35320',
#   'poster_image_thumbnail': None,
#   'slug': 'the-night-i-swam',
#   'title': 'The Night I Swam'},
#  {'id': '37827',
#   'poster_image_thumbnail': None,
#   'slug': 'dans-la-brume',
#   'title': 'Just a Breath Away'},
#  {'id': '20550',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wc9MgFWuBl3VS72w6VtiZXTgN79.jpg',
#   'slug': 'all-i-see-is-you',
#   'title': 'All I See Is You'},
#  {'id': '42302',
#   'poster_image_thumbnail': None,
#   'slug': 'marti',
#   'title': 'The Seagull'},
#  {'id': '44983',
#   'poster_image_thumbnail': None,
#   'slug': 'da-one-that-ghost-away',
#   'title': 'Da One That Ghost Away'},
#  {'id': '20588',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/d3qcpfNwbAMCNqWDHzPQsUYiUgS.jpg',
#   'slug': 'annihilation',
#   'title': 'Annihilation'},
#  {'id': '28564',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/1d20TbGRERlutpwtxG9C9qERGfU.jpg',
#   'slug': 'don-t-worry-he-won-t-get-far-on-foot',
#   'title': "Don't Worry, He Won't Get Far on Foot"},
#  {'id': '37980',
#   'poster_image_thumbnail': None,
#   'slug': 'balon',
#   'title': 'The Ball'},
#  {'id': '35067',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/2ui0HxKINUwmEfYpuUGP7GeoiQd.jpg',
#   'slug': 'grace-jones-bloodlight-and-bami',
#   'title': 'Grace Jones: Bloodlight and Bami'},
#  {'id': '35753',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vOrK1n6VgVCFBwgcq5tMoPCqa47.jpg',
#   'slug': 'd5ae49c5-117b-48f1-b5df-a59f8eab1fbc',
#   'title': 'Maquia: When the Promised Flower Blooms'},
#  {'id': '33465',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4hwrpBUT8U5juwEfJ3jaNgTml3o.jpg',
#   'slug': 'national-theatre-live-julius-caesar',
#   'title': 'National Theatre Live: Julius Caesar'},
#  {'id': '39166',
#   'poster_image_thumbnail': None,
#   'slug': 'sa-laenge-jeg-lever',
#   'title': None},
#  {'id': '20779',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5g8KDPGMr2zjyLKZEgKan9ZmcJO.jpg',
#   'slug': 'hostiles',
#   'title': 'Hostiles'},
#  {'id': '39167',
#   'poster_image_thumbnail': None,
#   'slug': 'sankt-bernhard-syndikatet',
#   'title': 'The Saint Bernard Syndicate'},
#  {'id': '39182',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xbmMa6us7ieIZZqAQ2wDMxkTh9Y.jpg',
#   'slug': 'den-skyldige',
#   'title': 'The Guilty'},
#  {'id': '41807',
#   'poster_image_thumbnail': None,
#   'slug': 'the-australien-ballett-2018-the-merry-widow',
#   'title': None},
#  {'id': '12114',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/jjBgi2r5cRt36xF6iNUEhzscEcb.jpg',
#   'slug': 'jurassic-world',
#   'title': 'Jurassic World'},
#  {'id': '42874',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/s4eoWQO9qb6dChmOMeqnsZtz6fl.jpg',
#   'slug': 'f8c02b00-a3d8-426b-a638-3c896ce44961',
#   'title': 'Gonjiam: Haunted Asylum'},
#  {'id': '45125',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/guViKKIY0D5UlfQcHnusB8zrJqc.jpg',
#   'slug': 'untitled-avengers',
#   'title': 'Untitled Avengers Movie'},
#  {'id': '41029',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/nu4RLtpS6jBGiUPzykxII7RHW91.jpg',
#   'slug': 'le-collier-rouge',
#   'title': 'The Red Collar'},
#  {'id': '32732',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/2IBgvP9GLjkTgixUh8FdU5DhQzS.jpg',
#   'slug': 'jusqu-a-la-garde',
#   'title': 'Custody'},
#  {'id': '43774',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/tNIbgFCyCscMWCc4QmS1fMjJF4d.jpg',
#   'slug': 'nothing-like-a-dame',
#   'title': 'Nothing Like a Dame'},
#  {'id': '27994',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/meuykFNb80ys6K0CZ9y0ZPZxCaW.jpg',
#   'slug': '1945',
#   'title': '1945'},
#  {'id': '39944',
#   'poster_image_thumbnail': None,
#   'slug': 'los-ojos-del-camino',
#   'title': None},
#  {'id': '42287',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/xUqimeu4KzFeqTvblNLvG8Y1DAo.jpg',
#   'slug': 'bent',
#   'title': 'Bent'},
#  {'id': '29477',
#   'poster_image_thumbnail': None,
#   'slug': 'grease-sing-a-long',
#   'title': None},
#  {'id': '29790',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/yZ8j8xKk2xQ1d88hB8YG6LZfRQj.jpg',
#   'slug': 'phantom-thread',
#   'title': 'Phantom Thread'},
#  {'id': '35853',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/sAtQcotXBPAJDBPYOl47lGid5X6.jpg',
#   'slug': 'backstabbing-for-beginners',
#   'title': 'Backstabbing for Beginners'},
#  {'id': '35580',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zDUWahnW7j0c31GrtiT5sfg2tPD.jpg',
#   'slug': 'razzia',
#   'title': 'Razzia'},
#  {'id': '35239',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qxJQ0VBCuJkJhJmuWzxI408ngwd.jpg',
#   'slug': 'the-15-17-to-paris',
#   'title': 'The 15:17 to Paris'},
#  {'id': '35476',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/3zhucK8SJInoYTpwIUCiJTgpNIZ.jpg',
#   'slug': 'der-hauptmann',
#   'title': 'The Captain'},
#  {'id': '34610',
#   'poster_image_thumbnail': None,
#   'slug': 'the-song-keepers',
#   'title': 'The Song Keepers'},
#  {'id': '35229',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/pUCZTll4Icq86LAWZyCxy8zFvXU.jpg',
#   'slug': 'ni-juge-ni-soumise',
#   'title': 'So Help Me God'},
#  {'id': '34065',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/uWzip7508IGjqNQJSNqLZN2KbjI.jpg',
#   'slug': 'sweet-country',
#   'title': 'Sweet Country'},
#  {'id': '45626',
#   'poster_image_thumbnail': None,
#   'slug': '13ebc01a-a790-4cfb-8720-99a2ffd3d807',
#   'title': 'Cycle'},
#  {'id': '26290',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/49sb3kEZplzudQBhJDSt0mNJm4V.jpg',
#   'slug': 'the-endless',
#   'title': 'The Endless'},
#  {'id': '44372',
#   'poster_image_thumbnail': None,
#   'slug': 'on-a-20-ans-pour-changer-le-monde',
#   'title': None},
#  {'id': '24704',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/yzSfG8TLAqw7nMQh2lxirQkQpgs.jpg',
#   'slug': 'thelma',
#   'title': 'Thelma'},
#  {'id': '27506',
#   'poster_image_thumbnail': None,
#   'slug': 'd7e0bafd-4e7e-442b-bd65-2b454479a24b',
#   'title': 'Masha and the Bear - To the Cinema'},
#  {'id': '20621',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cW3WT37eISXx8yDkllArzRbdd45.jpg',
#   'slug': 'delirium',
#   'title': 'Delirium'},
#  {'id': '28559',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/8EfNuERL9weFWblnMUabinB2Gwb.jpg',
#   'slug': 'a083080d-0d81-456a-bf36-9b530e528d4a',
#   'title': 'A Gentle Creature'},
#  {'id': '32536',
#   'poster_image_thumbnail': None,
#   'slug': 'blank-13',
#   'title': 'blank 13'},
#  {'id': '45135',
#   'poster_image_thumbnail': None,
#   'slug': 'la-terre-vue-du-coeur',
#   'title': 'Earth: Seen From The Heart'},
#  {'id': '33895',
#   'poster_image_thumbnail': None,
#   'slug': 'le-semeur',
#   'title': 'The Sower'},
#  {'id': '32341',
#   'poster_image_thumbnail': None,
#   'slug': 'edie',
#   'title': 'Edie'},
#  {'id': '43522',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/70UuQuERBIIabkROcBj1LQPa1vC.jpg',
#   'slug': 'nul-homme-n-est-une-ile',
#   'title': 'No Man Is an Island'},
#  {'id': '43543',
#   'poster_image_thumbnail': None,
#   'slug': 'vom-bauen-der-zukunft-100-jahre-bauhaus',
#   'title': None},
#  {'id': '34865',
#   'poster_image_thumbnail': None,
#   'slug': 'stebuklas',
#   'title': 'Miracle'},
#  {'id': '35342',
#   'poster_image_thumbnail': None,
#   'slug': 'je-vais-mieux',
#   'title': None},
#  {'id': '42143',
#   'poster_image_thumbnail': None,
#   'slug': 'matti-sami-und-die-drei-grossten-fehler-des-universums',
#   'title': None},
#  {'id': '3334',
#   'poster_image_thumbnail': None,
#   'slug': 'der-zauberer-von-oz',
#   'title': None},
#  {'id': '30581',
#   'poster_image_thumbnail': None,
#   'slug': 'nothingwood',
#   'title': 'The Prince of Nothingwood'},
#  {'id': '43586',
#   'poster_image_thumbnail': None,
#   'slug': 'de-matchmaker',
#   'title': 'The Matchmaker'},
#  {'id': '20921',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/tyCt5dQ2yhfEtWcP3KqMgtFk7s0.jpg',
#   'slug': 'how-to-talk-to-girls-at-parties',
#   'title': 'How to Talk to Girls at Parties'},
#  {'id': '27557',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/uguWEoZelSSckxgiQctlkZ6gpfU.jpg',
#   'slug': 'testrol-es-lelekrol',
#   'title': 'On Body and Soul'},
#  {'id': '39932',
#   'poster_image_thumbnail': None,
#   'slug': 'anime-night-2018-detektiv-conan-special-episode-one-the-great-detective-turned-small',
#   'title': None},
#  {'id': '43912',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/6ZKbogDg0VvtiicHzSC4nsINdqt.jpg',
#   'slug': 'after-auschwitz',
#   'title': 'After Auschwitz'},
#  {'id': '31944',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/87oy4bxwkhmb4Jb3MRvosvd9NOX.jpg',
#   'slug': 'film-stars-don-t-die-in-liverpool',
#   'title': "Film Stars Don't Die in Liverpool"},
#  {'id': '44395',
#   'poster_image_thumbnail': None,
#   'slug': 'golak-bugni-bank-te-batua',
#   'title': None},
#  {'id': '26501',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/dJQANdeyDDeVCR8yGxLy4bwJKXP.jpg',
#   'slug': 'ce-qui-nous-lie',
#   'title': 'Back to Burgundy'},
#  {'id': '30351',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/6rn170WmFUE4esoXvoOOAonDw16.jpg',
#   'slug': 'the-mercy',
#   'title': 'The Mercy'},
#  {'id': '44385',
#   'poster_image_thumbnail': None,
#   'slug': 'candelaria-351598',
#   'title': 'Candelaria'},
#  {'id': '26592',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wh1f7peigW0qUXXwynwVAt7axZd.jpg',
#   'slug': 'category-5',
#   'title': 'The Hurricane Heist'},
#  {'id': '42788',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/x4ppWRGH3pfVmEsbNC8UhvZVswd.jpg',
#   'slug': 'all-that-jazz',
#   'title': 'All That Jazz'},
#  {'id': '33099',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qnGe4uG4FqDTNsGCcxeyaGA6Dih.jpg',
#   'slug': 'djam',
#   'title': 'Djam'},
#  {'id': '42065',
#   'poster_image_thumbnail': None,
#   'slug': 'la-tribu',
#   'title': None},
#  {'id': '35910',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4UnME3icxSspwL0UoGZNSyyp7Xs.jpg',
#   'slug': 'every-day',
#   'title': 'Every Day'},
#  {'id': '35486',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5aAjVARbO0zy17oxK53MbkFB75R.jpg',
#   'slug': 'una-especie-de-familia',
#   'title': 'A Sort of Family'},
#  {'id': '40777',
#   'poster_image_thumbnail': None,
#   'slug': 'vent-du-nord',
#   'title': 'Vent du nord'},
#  {'id': '43643',
#   'poster_image_thumbnail': None,
#   'slug': 'far-til-fire-i-solen',
#   'title': None},
#  {'id': '13931',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/n6n0rMFsQhdNoMygr2pyL26wUfM.jpg',
#   'slug': 'the-east',
#   'title': 'The East'},
#  {'id': '28782',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zFaOo1uFhPsDHnJuSJ8Fj62pmhM.jpg',
#   'slug': 'weit-ein-weg-um-die-welt',
#   'title': 'FAR. The Story of a Journey around the World'},
#  {'id': '32509',
#   'poster_image_thumbnail': None,
#   'slug': 'rangasthalam1985',
#   'title': 'Rangasthalam'},
#  {'id': '24838',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/qlrhwUDe7YOZujAYanK6ij2vbY5.jpg',
#   'slug': 'loving-vincent',
#   'title': 'Loving Vincent'},
#  {'id': '30890',
#   'poster_image_thumbnail': None,
#   'slug': 'hilfe-ich-habe-meine-eltern-geschrumpft',
#   'title': 'Help, I Shrunk My Parents'},
#  {'id': '9171',
#   'poster_image_thumbnail': None,
#   'slug': 'carmen-live-aus-der-metropolitan-opera-new-york',
#   'title': None},
# ...
#   'poster_image_thumbnail': None,
#   'slug': 'jerusalem',
#   'title': 'P.S. Jerusalem'},
#  {'id': '5384',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/6VaP1H3MOW5jdkWqS5Q1NapCOS6.jpg',
#   'slug': 'billy-elliot-i-will-dance',
#   'title': 'Billy Elliot'},
#  {'id': '6376',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/iyTD2QnySNMPUPE3IedZQipSWfz.jpg',
#   'slug': 'wilde-erdbeeren',
#   'title': 'Wild Strawberries'},
#  {'id': '6473',
#   'poster_image_thumbnail': None,
#   'slug': 'matrix-reloaded',
#   'title': None},
#  {'id': '9697',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/eUfj1NXxd7yIiCrqAOUm1MYL2CQ.jpg',
#   'slug': 'die-rechnung-ging-nicht-auf',
#   'title': 'The Killing'},
#  {'id': '11375',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/eGe4mIFdoBC5OzAsoy6GAW6yDcg.jpg',
#   'slug': 'falsche-bewegung',
#   'title': 'Wrong Move'},
#  {'id': '11513',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/Agm2t5G5ctiCDwo5U0gMt1TyQx.jpg',
#   'slug': 'alice-in-den-staedten',
#   'title': 'Alice in the Cities'},
#  {'id': '18843',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/s0C78plmx3dFcO3WMnoXCz56FiN.jpg',
#   'slug': 'sing-street',
#   'title': 'Sing Street'},
#  {'id': '19652',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/zhWgqtSOWmxckHMjJRCxJqjqfSN.jpg',
#   'slug': 'eine-komoedie-im-mai',
#   'title': 'May Fools'},
#  {'id': '20709',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4QD9bXJHOtnR7YfvmGjv8n1HTfu.jpg',
#   'slug': 'reparer-les-vivants',
#   'title': 'Heal the Living'},
#  {'id': '21080',
#   'poster_image_thumbnail': None,
#   'slug': 'back-for-good',
#   'title': None},
#  {'id': '23881',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/mSBUClLuB70a2unFvW4m48OG9VF.jpg',
#   'slug': 'diary-of-a-wimpy-kid-the-long-haul',
#   'title': 'Diary of a Wimpy Kid: The Long Haul'},
#  {'id': '6764',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/oJpOYPpVWyPeunGbbDGH1KFvea0.jpg',
#   'slug': 'der-grosse-gatsby-f14333',
#   'title': 'The Great Gatsby'},
#  {'id': '13556',
#   'poster_image_thumbnail': None,
#   'slug': 'effi-briest-f11956',
#   'title': 'Effi Briest'},
#  {'id': '20496',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/1pHOqpdCYNmtRVJs6pGKQKttrPm.jpg',
#   'slug': 'the-lego-batman-movie',
#   'title': 'The Lego Batman Movie'},
#  {'id': '26368',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/fchHLsLjFvzAFSQykiMwdF1051.jpg',
#   'slug': 'pitch-perfect-3',
#   'title': 'Pitch Perfect 3'},
#  {'id': '26885',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/2WauUg4DcUxng5nwhisu7UFZq4Z.jpg',
#   'slug': 'an-inconvenient-sequel',
#   'title': 'An Inconvenient Sequel: Truth to Power'},
#  {'id': '26891',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cE6c62sce6uGA7jQQbeYKssgh96.jpg',
#   'slug': 'in-zeiten-des-abnehmenden-lichts',
#   'title': 'In Times of Fading Light'},
#  {'id': '28275',
#   'poster_image_thumbnail': None,
#   'slug': 'drom-vidare',
#   'title': 'Beyond Dreams'},
#  {'id': '29281',
#   'poster_image_thumbnail': None,
#   'slug': 'die-migrantigen',
#   'title': None},
#  {'id': '30016',
#   'poster_image_thumbnail': None,
#   'slug': 'uzak-167747',
#   'title': 'Uzak'},
#  {'id': '30163',
#   'poster_image_thumbnail': None,
#   'slug': 'la-belle-au-bois-dormant',
#   'title': None},
#  {'id': '32009',
#   'poster_image_thumbnail': None,
#   'slug': 'gabriel-e-a-montanha',
#   'title': 'Gabriel and the Mountain'},
#  {'id': '32787',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5z2vuJk6P7V2azw3gWQF7L4l5xU.jpg',
#   'slug': 'kedi',
#   'title': 'Kedi'},
#  {'id': '33865',
#   'poster_image_thumbnail': None,
#   'slug': 'chien',
#   'title': 'Dog'},
#  {'id': '36694',
#   'poster_image_thumbnail': None,
#   'slug': 'leaning-into-the-wind-andy-goldsworthy-347616',
#   'title': None},
#  {'id': '38386',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/i7zGvuM2Z22m7gx0QKDNEnzWGQr.jpg',
#   'slug': 'el-cuaderno-de-sara',
#   'title': "Sara's Notebook"},
#  {'id': '39710',
#   'poster_image_thumbnail': None,
#   'slug': 'godzilla-a0f811cf-1b0c-4b74-9302-700543e76bac',
#   'title': 'GODZILLA: City on the Edge of Battle'},
#  {'id': '34967',
#   'poster_image_thumbnail': None,
#   'slug': 'hannah-buddhism-s-untold-journey',
#   'title': "Hannah: Buddhism's Untold Journey"},
#  {'id': '45604',
#   'poster_image_thumbnail': None,
#   'slug': 'double-feature-jurassic-world',
#   'title': None},
#  {'id': '4798',
#   'poster_image_thumbnail': None,
#   'slug': 'das-dschungelbuch',
#   'title': None},
#  {'id': '4834',
#   'poster_image_thumbnail': None,
#   'slug': 'das-fenster-zum-hof',
#   'title': "'Rear Window' Ethics: Remembering and Restoring a Hitchcock Classic"},
#  {'id': '4973',
#   'poster_image_thumbnail': None,
#   'slug': 'lauras-stern-und-die-traummonster',
#   'title': 'Lauras Stern und die Traummonster'},
#  {'id': '4993',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/29veIwD38rVL2qY74emXQw4y25H.jpg',
#   'slug': 'full-metal-jacket',
#   'title': 'Full Metal Jacket'},
#  {'id': '5138',
#   'poster_image_thumbnail': None,
#   'slug': 'the-wizard-of-gore',
#   'title': None},
#  {'id': '6451',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/ihC083U7ef56Ui4x0P0dobojrZ1.jpg',
#   'slug': 'der-fremde-im-zug',
#   'title': 'Strangers on a Train'},
#  {'id': '7725',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4x34alatxSgOZXZvn92cCY5mDg6.jpg',
#   'slug': 'die-abenteuer-des-prinzen-achmed',
#   'title': 'The Adventures of Prince Achmed'},
#  {'id': '8200',
#   'poster_image_thumbnail': None,
#   'slug': 'der-kleine-rabe-socke-das-grosse-rennen',
#   'title': 'Raven the Little Rascal - The Big Race'},
#  {'id': '9451',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/bHFmAWaUuzrok2khfLS85xeBqpO.jpg',
#   'slug': 'killer-s-kiss',
#   'title': "Killer's Kiss"},
#  {'id': '9663',
#   'poster_image_thumbnail': None,
#   'slug': 'wettbewerb',
#   'title': None},
#  {'id': '10130',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/3zQvuSAUdC3mrx9vnSEpkFX0968.jpg',
#   'slug': 'baymax-riesiges-robowabohu-3d',
#   'title': 'Big Hero 6'},
#  {'id': '11063',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/uwO4ZfWEaw1rD3keRW3QcjPcjzE.jpg',
#   'slug': 'verdammt-in-alle-ewigkeit',
#   'title': 'From Here to Eternity'},
#  {'id': '14196',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4ucLGcXVVSVnsfkGtbLY4XAius8.jpg',
#   'slug': 'der-exorzist',
#   'title': 'The Exorcist'},
#  {'id': '14837',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/4Zz2aX5ZrwebgxdIhPCXBKxFSVO.jpg',
#   'slug': 'dancer-in-the-dark',
#   'title': 'Dancer in the Dark'},
#  {'id': '16645',
#   'poster_image_thumbnail': None,
#   'slug': 'die-unendliche-geschichte-iii',
#   'title': None},
#  {'id': '18000',
#   'poster_image_thumbnail': None,
#   'slug': 'die-zeit-mit-monika',
#   'title': None},
#  {'id': '18371',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/brECyRPAWJS1clF0unAC3MtERMA.jpg',
#   'slug': 'die-nacht-des-jaegers',
#   'title': 'The Night of the Hunter'},
#  {'id': '20418',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5AT8JdBX4NoE2WdAeXRIGWtaij.jpg',
#   'slug': 'stick-man',
#   'title': 'Stick Man'},
#  {'id': '20845',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5PDT64gtbmH10gK5AYR7LZh5PQk.jpg',
#   'slug': 'dangal',
#   'title': 'Dangal'},
#  {'id': '25951',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/5q4rDRt2JAEtU5B3kwYlBLYjHLa.jpg',
#   'slug': 'the-nile-hilton-incident',
#   'title': 'The Nile Hilton Incident'},
#  {'id': '26141',
#   'poster_image_thumbnail': None,
#   'slug': '4-quatuor-ebene',
#   'title': '4'},
#  {'id': '26599',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/vlDFEhlBon98itV43QOPCk7r0I7.jpg',
#   'slug': 'muse',
#   'title': 'Muse'},
#  {'id': '27285',
#   'poster_image_thumbnail': None,
#   'slug': 'patients',
#   'title': 'Patients'},
#  {'id': '27315',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/raEMFyklFKgqTf7iTerHo4uBRfC.jpg',
#   'slug': 'bamui-haebyun-eoseo-honja',
#   'title': 'On the Beach at Night Alone'},
#  {'id': '28409',
#   'poster_image_thumbnail': None,
#   'slug': 'belle-et-sebastien-3',
#   'title': None},
#  {'id': '31459',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/8dTtG54rJbg3HWxFptUageWcfBD.jpg',
#   'slug': 'crash-test-aglae',
#   'title': 'Crash Test Aglaé'},
#  {'id': '32165',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/m800lQEOeSB8xHCSDVPvllxqdMK.jpg',
#   'slug': '401f7553-6d15-4ee0-9012-7a7719353985',
#   'title': 'Arrhythmia'},
#  {'id': '33356',
#   'poster_image_thumbnail': None,
#   'slug': 'opera-national-de-paris-2017-18-don-pasquale',
#   'title': None},
#  {'id': '33831',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/3CkwSE6Q1UtQbRb270D9s741yRx.jpg',
#   'slug': 'vinterbrodre',
#   'title': 'Winter Brothers'},
#  {'id': '33886',
#   'poster_image_thumbnail': None,
#   'slug': 'dene-wos-guet-geit',
#   'title': 'Those Who Are Fine'},
#  {'id': '33925',
#   'poster_image_thumbnail': None,
#   'slug': 'la-douleur',
#   'title': 'Memoir of Pain'},
#  {'id': '36211',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/dUyuFFEttYTqqVBXtwCLGhQbNJp.jpg',
#   'slug': 'le-lion-est-mort-ce-soir',
#   'title': 'The Lion Sleeps Tonight'},
#  {'id': '38114',
#   'poster_image_thumbnail': None,
#   'slug': 'miracle-on-42nd-street',
#   'title': 'Miracle on 42nd Street'},
#  {'id': '39883',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/2RmJY7cN90bpRfSuo4wql9onwqV.jpg',
#   'slug': 'aeroporto-central',
#   'title': 'Central Airport THF'},
#  {'id': '40464',
#   'poster_image_thumbnail': None,
#   'slug': 'wann-wird-es-endlich-wieder-sommer',
#   'title': None},
#  {'id': '40800',
#   'poster_image_thumbnail': None,
#   'slug': 'vitello',
#   'title': 'Vitello'},
#  {'id': '40944',
#   'poster_image_thumbnail': None,
#   'slug': '7bba7231-aa08-4b29-ae7b-57db94a4714b',
#   'title': 'Liverleaf'},
#  {'id': '41060',
#   'poster_image_thumbnail': None,
#   'slug': '2d64d01c-e3a2-40a5-806b-86f8fbec3911',
#   'title': 'Titanic'},
#  {'id': '41327',
#   'poster_image_thumbnail': None,
#   'slug': 'guardians-of-the-earth',
#   'title': None},
#  {'id': '42621',
#   'poster_image_thumbnail': None,
#   'slug': 'psyche',
#   'title': 'Climax'},
#  {'id': '44466',
#   'poster_image_thumbnail': None,
#   'slug': 'the-hangman',
#   'title': 'The Hangman'},
#  {'id': '43951',
#   'poster_image_thumbnail': None,
#   'slug': 'knutsen-ludvigsen-og-den-faele-rasputin',
#   'title': None},
#  {'id': '44393',
#   'poster_image_thumbnail': None,
#   'slug': 'bolshoi-ballett-2018-19-la-bayadere',
#   'title': None},
#  {'id': '45000',
#   'poster_image_thumbnail': None,
#   'slug': 'wunder-der-wirklichkeit',
#   'title': None},
#  {'id': '3385',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/f3DEXseCs3WBtvCv9pVPCtoluuG.jpg',
#   'slug': 'wege-zum-ruhm',
#   'title': 'Paths of Glory'},
#  {'id': '4313',
#   'poster_image_thumbnail': None,
#   'slug': 'national-theatre-london-the-curious-incident-of-the-dog-in-the-night-time',
#   'title': None},
#  {'id': '4929',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/jRx1nDUA4sb2NEKQaukXKBz6pCf.jpg',
#   'slug': 'monty-python-ritter-der-kokosnuss',
#   'title': 'Monty Python and the Holy Grail'},
#  {'id': '5385',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/sFLgxvtK9vxbNq502peVJ847Owp.jpg',
#   'slug': 'fuer-eine-handvoll-dollar',
#   'title': 'A Fistful of Dollars'},
#  {'id': '5573',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/rVAHRtAMhV8QVXQMQ8NxNbZXCDp.jpg',
#   'slug': 'spiel-mir-das-lied-vom-tod',
#   'title': 'Once Upon a Time in the West'},
#  {'id': '6389',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/tuKO2PLGDcJj5vpfAYKSQcnLEpD.jpg',
#   'slug': 'meine-nachbarn-die-yamadas',
#   'title': 'My Neighbors the Yamadas'},
#  {'id': '7290',
#   'poster_image_thumbnail': None,
#   'slug': 'moulin-rouge-das-ballett',
#   'title': None},
#  {'id': '8928',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/rjw7tQbiBnbIeufyEt02oVickDM.jpg',
#   'slug': 'in-der-glut-des-suedens',
#   'title': 'Days of Heaven'},
#  {'id': '9015',
#   'poster_image_thumbnail': None,
#   'slug': 'tokyo-drifter-der-mann-aus-tokio',
#   'title': 'Delinquent Girl Boss: Tokyo Drifters'},
#  {'id': '10698',
#   'poster_image_thumbnail': None,
#   'slug': 'martha-f16371',
#   'title': 'Martha'},
#  {'id': '13557',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/e1RGbJFQeDLVeUsbtz1ZuzcA0x2.jpg',
#   'slug': 'die-bitteren-traenen-der-petra-von-kant',
#   'title': 'The Bitter Tears of Petra von Kant'},
#  {'id': '15379',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/o4cYWubhrBFF56IyEyce89lMb5y.jpg',
#   'slug': 'die-nacht-vor-der-hochzeit',
#   'title': 'The Philadelphia Story'},
#  {'id': '17113',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/kXTwdYQTYb5lUNRSRPgyAwjUkrv.jpg',
#   'slug': 'die-winzlinge-operation-zuckerdose',
#   'title': 'Minuscule: Valley of the Lost Ants'},
#  {'id': '18733',
#   'poster_image_thumbnail': None,
#   'slug': 'cafe-belgica',
#   'title': 'Belgica'},
#  {'id': '24416',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/jLzfHNU1JldQpC5TNEvQMnWQxx6.jpg',
#   'slug': 'paris-can-wait',
#   'title': 'Paris Can Wait'},
#  {'id': '28030',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/lPHDE5tSVyUyxKdn7VHDKyHbtWc.jpg',
#   'slug': 'acht-stunden-sind-kein-tag',
#   'title': "Eight Hours Don't Make a Day"},
#  {'id': '28252',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/szoZ6rxMbOR9ctCxwzzzrxkuSd9.jpg',
#   'slug': 'walk-with-me',
#   'title': 'Walk with Me'},
#  {'id': '29273',
#   'poster_image_thumbnail': None,
#   'slug': 'maleika',
#   'title': None},
#  {'id': '30283',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/rQc8aGHeJ65pkFabXVjPZpcodVh.jpg',
#   'slug': 'les-fantomes-d-ismael',
#   'title': "Ismael's Ghosts"},
#  {'id': '30320',
#   'poster_image_thumbnail': None,
#   'slug': '12-jours',
#   'title': '12 Days'},
#  {'id': '31001',
#   'poster_image_thumbnail': None,
#   'slug': 'sans-adieu',
#   'title': 'No Farewells'},
#  {'id': '31038',
#   'poster_image_thumbnail': None,
#   'slug': 'the-bolshoi-ballet-giselle',
#   'title': None},
#  {'id': '31557',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/2MKyqhM5CfuFBdIc3vFtkrLZfCS.jpg',
#   'slug': 'barbara-cc22f4ee-1761-4f9e-9f3a-753b3d710bfa',
#   'title': 'Barbara'},
#  {'id': '32746',
#   'poster_image_thumbnail': None,
#   'slug': 'droles-de-petites-betes',
#   'title': 'Tall Tales'},
#  {'id': '34132',
#   'poster_image_thumbnail': None,
#   'slug': 'ouaga-girls',
#   'title': 'Ouaga Girls'},
#  {'id': '34357',
#   'poster_image_thumbnail': None,
#   'slug': 'banana-pancakes-and-the-children-of-sticky-rice',
#   'title': None},
#  {'id': '35350',
#   'poster_image_thumbnail': None,
#   'slug': 'l-ordine-delle-cose',
#   'title': None},
#  {'id': '35402',
#   'poster_image_thumbnail': None,
#   'slug': 'die-letzte-pointe',
#   'title': 'Die letzte Pointe'},
#  {'id': '35619',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/p2UylV0hPefEuWPFMo1r56vu2nb.jpg',
#   'slug': 'first-reformed',
#   'title': 'First Reformed'},
#  {'id': '36240',
#   'poster_image_thumbnail': None,
#   'slug': 'rusty-boys-cae86037-7902-4250-9639-42909d01e4d4',
#   'title': 'Rusty Boys'},
#  {'id': '36941',
#   'poster_image_thumbnail': None,
#   'slug': 'menina',
#   'title': None},
#  {'id': '39343',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/cWNc8JfVRQpPlFfGsNOCsup9SNg.jpg',
#   'slug': 'gekijouban-fate-stay-night-heaven-s-feel-i-presage-flower',
#   'title': "Fate/stay night: Heaven's Feel I. presage flower"},
#  {'id': '39962',
#   'poster_image_thumbnail': 'http://image.tmdb.org/t/p/w154/wihYuMsQADWrSaVThaJunM2wR4V.jpg',
#   'slug': 'hereditary',
#   'title': 'Hereditary'},
#  {'id': '42033',
#   'poster_image_thumbnail': None,
#   'slug': 'l-insoumis',
#   'title': None},
#  {'id': '42118',
#   'poster_image_thumbnail': None,
#   'slug': 'amelia',
#   'title': None},
#  {'id': '42595',
#   'poster_image_thumbnail': None,
#   'slug': 'die-wunderubung',
#   'title': None},
#  {'id': '42777',
#   'poster_image_thumbnail': None,
#   'slug': 'trait-de-vie',
#   'title': None},
#  ...]

# %% [markdown]
# #### Get all cinemas in a zipcode

# %%
def cinemas_in_zipcode(zipcode):
    cinemas_in_zipcode = []
    for cinema in NYCcinemas:
        if cinema['location']['address']['zipcode'] == zipcode:
            cinemas_in_zipcode.append(cinema)
    return cinemas_in_zipcode

# %% [markdown]
# #### Get showtimes of all genres of all cinemas in a zipcode
# Only showtimes of current day and after current time

# %%
def genres_showtimes_in_zipcode(zipcode):
    
    # Get all showtimes of all cinemas in a specific zipcode 
    showtimes_in_zipcode = []
    
    for cinema in cinemas_in_zipcode(zipcode):        
        cinema_id = cinema['id']
        ishowtimes_url = "https://api.internationalshowtimes.com/v4/showtimes/?cinema_id={}".format(cinema_id)
        headers = {"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
        cinema_showtimes = requests.get(ishowtimes_url,headers = headers).json()['showtimes']

        showtimes_in_zipcode.append(cinema_showtimes)
            
    # Get showtimes (only current day after current time) for all movies of each genre
    genres_showtimes_in_zipcode = [] 
    
    for genre in genres_ids:
        genre_showtimes_in_zipcode = []
        
        for cinema in showtimes_in_zipcode:
            for movie in cinema:
                criterion1 = movie['movie_id'] in genre
                # API gives the local time with a time zone offset in hours and minutes
                # Positive offset: local time is ahead of UTC; Negative offset: local time is behind UTC
                # UTC (Coordinated Universal Time) is 4 hours ahead of EDT (Eastern Daylight Time)
                # eg: 2018-01-01T15:30:00-04:00 
                # 2018-01-01T15:30:00 in EDT
                # 2018-01-01T19:30:00 in UTC
                criterion2 = movie['start_at'].startswith(datetime.now(tz=est).strftime('%Y-%m-%d'))                
                criterion3 = est.localize(datetime.strptime(movie['start_at'],'%Y-%m-%dT%H:%M:%S-04:00')) > datetime.now(tz=est)
                if criterion1 and criterion2 and criterion3:
                    genre_showtimes_in_zipcode.append(movie)
                    
        genres_showtimes_in_zipcode.append(genre_showtimes_in_zipcode)
        
    return genres_showtimes_in_zipcode

# %% [markdown]
# #### Get showtimes of a specific genre

# %%
def genre_showtimes_selected(zipcode, genre_title):

    for genre in genres:
        if genre['title'] == genre_title:
            genre_loc = int(genre['id'])
            if genre_loc >= 10:
                genre_loc -= 1
                
    return genres_showtimes_in_zipcode(zipcode)[genre_loc]

# %% [markdown]
# ####  Final results

# %%
def results(zipcode, genre_title):
    results = []
    
    for showtime in genre_showtimes_selected(zipcode, genre_title):
        info = {}
        
        for movie in movies_ids_titles:
            if movie['id'] == showtime['movie_id']:
                info['Title'] = movie['title']
                info["Poster link"] = movie['poster_image_thumbnail']
                
        for cinema in cinemas_in_zipcode(zipcode):
            if cinema['id'] == showtime['cinema_id']:
                info['Cinema'] = cinema['name']
                info["Location"] = cinema['location']['address']['display_text']
                
        info["Start at"] = showtime['start_at'].replace("T", " ").replace("-04:00","")
        results.append(info)

    
    return results

# %% [markdown]
# ### Sentiment Analysis

# %% [markdown]
# Now that we have functions to fetch movies and movie times based on genre and zipcode, we want to be able to determine what genre the user should watch.  To do this, we will ask them some questions and do a sentiment analysis of thier responses.

# %%
def getSentiment(text):
    #Use IBM Watson API to perform a sentiment analysis on the text we will get from the user input
    endpoint = "https://gateway.watsonplatform.net/natural-language-understanding/api/v1/analyze"

   
    username = "25a70137-e1e3-4e34-8ca3-daffb770c96b"
    password = "4NrzHVNT7KBj"

    parameters = {
        'features': 'emotion,sentiment',
        'version' : '2017-03-16',
        'text': text,
        'language' : 'en',
    }

    resp = requests.get(endpoint, params=parameters, auth=(username, password))
    
    return resp.json()

# %%
print("Hi, I am looking forward to helping you choose a movie for tonight. Please answer each question I ask in one or two sentences.")
# Out:
# Hi, I am looking forward to helping you choose a movie for tonight. Please answer each question I ask in one or two sentences.

# %% [markdown]
# We want to ask users random questions and take their input to analyze their mood.

# %%
answer1 = input("What is the most exciting thing that happened to you today? ")
# Out:
# What is the most exciting thing that happened to you today? photos

# %%
answer2 = input("What are you looking forward to tonight? ")
# Out:
# What are you looking forward to tonight? drinks

# %%
answer3 = input("If you were granted one wish right now, what would you wish for? (don't ask for more wishes...) ")
# Out:
# If you were granted one wish right now, what would you wish for? (don't ask for more wishes...) nothing

# %%
answer4 = input("Describe the weather outside. ")
# Out:
# Describe the weather outside. stormy

# %%
answer5 = input("How are you feeling today? ")
print("Thanks! We're finding the perfect movie for your mood.")
# Out:
# How are you feeling today? good
# Thanks! We're finding the perfect movie for your mood.

# %%
zipcode = input("Finally, what is your zipcode? ")
# Out:
# Finally, what is your zipcode? 10035

# %%
#Put all the answers into one string to be analyzed by the watson API
answers = answer1 + " " + answer2 + " " + answer3 + " " + answer4 + " " + answer5

# %% [markdown]
# Run the getSentiment function defined above to get the sentiment of the user responses.  Store the results

# %%
data = getSentiment(answers)
#Not necessary for the program, but print sentiment analysis results to see that it worked
data
# Out:
# {'emotion': {'document': {'emotion': {'anger': 0.058538,
#     'disgust': 0.07813,
#     'fear': 0.02014,
#     'joy': 0.727802,
#     'sadness': 0.093674}}},
#  'language': 'en',
#  'sentiment': {'document': {'label': 'neutral', 'score': 0.0}},
#  'usage': {'features': 2, 'text_characters': 33, 'text_units': 1}}

# %% [markdown]
# Access just the "emotion" dictionary from the getSentiment output and store it

# %%
emotions = data["emotion"]["document"]["emotion"]

# %% [markdown]
# Assign genres that correspond to each dominant emotion.
# e.g. If anger has a higher percentage than the other 4 emotions, recommend Action, War, and Western

# %%
if emotions["anger"] > emotions["disgust"] and emotions["anger"] > emotions["fear"] and emotions["anger"] > emotions["joy"] and emotions["anger"] > emotions["sadness"]:
    #Action, War, and Western to act as an outlet for the anger
    genre_id = [0,15,16]

if emotions["disgust"] > emotions["anger"] and emotions["disgust"] > emotions["fear"] and emotions["disgust"] > emotions["joy"] and emotions["disgust"] > emotions["sadness"]: 
    #Crime, Documentary, and Romance to cater to different kinds of disgust the user may be feeling
    genre_id = [4,5,12]
  
    
if emotions["fear"] > emotions["anger"] and emotions["fear"] > emotions["disgust"] and emotions["fear"] > emotions["joy"] and emotions["fear"] > emotions["sadness"]:
    #Horror, Sci-Fi, and Thriller for the user already in a fearful mood
    genre_id = [10,13,14]


if emotions["joy"] > emotions["anger"] and emotions["joy"] > emotions["fear"] and emotions["joy"] > emotions["disgust"] and emotions["joy"] > emotions["sadness"]:
    #Animation, Comedy, and Family for the happy user 
    genre_id = [2,3,7]


else:
    #If the user is sad, they get a variety of options -- Advernture, Drama, Foreign, and Mystery 
    genre_id = [1,6,8,11]

# %% [markdown]
# Sort zipcodes by neighborhood, and find the movie times for all the theaters in the neighborhood (not just in the zipcode).  Some zipcodes don't have movie theaters in the ishowtames database, and we wanted to give the users more options.

# %%
zipcodes = [
    ("10026", "10027", "10030", "10037", "10039"),
    ("10001", "10011", "10018", "10019", "10020", "10036"),
    ("10029", "10035"),
    ("10010", "10016", "10017", "10022"),
    ("10012", "10013", "10014"),
    ("10004", "10005", "10006", "10007", "10038", "10281"),
    ("10002", "10003", "10009"),
    ("10021", "10028", "10044", "10065", "10075", "10128"),
    ("10023", "10024", "10025"),
    ("10031", "10032", "10033", "10034", "10040")
]

# %% [markdown]
# Get the list of all the zipcodes in the neighborhood from the zipcodes dictionary based on the user's zipcode input.  Some neighborhoods don't have any theaters listed in the ishowtimes database, so we reassigned the zipcodes in those neighborhoods to the nearest neighborhood.

# %%
def getZipcodes(zipcode):
    if zipcode == '10013':
        zip_list = zipcodes[5]
    elif zipcode == '10012':
        zip_list = zipcodes[6]
    elif zipcode == '10029':
        zip_list = zipcodes[7]
    elif zipcode == '10035' or zipcode in zipcodes[9]:
        zip_list = zipcodes[0]
    elif zipcode == '10014':
        zip_list = zipcodes[1]
    else:    
        for neighborhood in zipcodes:
            for code in neighborhood:
                if code == zipcode:
                    zip_list = neighborhood
    return zip_list

# %%
#Store the zipcodes as their own list
zips = getZipcodes(zipcode)
zips
# Out:
# ('10026', '10027', '10030', '10037', '10039')

# %% [markdown]
# Get the results for all movie times for the genres and zipcodes corresponding to the user's input.  Store them in an array.

# %%
all_results = []
for genre in genre_id:
    for code in zips:
        movie_results = results(code, genres[genre]["title"])
        for result in movie_results:
            #This takes care of the issue pointed out in the class presentation
            #Some movies (namely Isle of Dogs) were being double counted... 
            #because they fit more than one genre recommended for one sentiment
            #Now, there should be no duplicates becasue the result is only appended...
            #if it doesn't already exist in the all_results array
            if not result in all_results:
                all_results.append(result)
            
all_results
# Out:
# []

# %% [markdown]
# To display the results in a way that's easier to read, we can create a pandas dataframe with the data. The output is the final results the user will receive.

# %%
movie_data = pd.DataFrame(all_results)
if len(movie_data) == 0:
    movies = "Sorry, there are no more showings tonight in your area to match your mood."
else:
    movies = movie_data.sort_values(by=['Start at'])

movies
# Out:
# 'Sorry, there are no more showings tonight in your area to match your mood.'

# %% [markdown]
# # Going from back end to front end with Flask
# Below you will find the code from our .py and .html notebooks that we used to create the front end aspect of this data product.  We took the code we used in our backend (presented above), and modified it slightly to better operate with Flask.  The main modification was using fewer functions to perform the same tasks.

# %% [markdown]
# ## questionnaire.py

# %% [markdown]
# ```python
# from flask import Flask, render_template, request
# app = Flask(__name__)
# import requests
# import json
# import pandas as pd
# from datetime import datetime
# from pytz import timezone
# est = timezone('US/Eastern')
#
# @app.route('/')
# def student():
#     return render_template('user_inputs.html')
#
# @app.route('/result',methods = ['POST'])
# def result():
#     answer1 = request.form['Q1']
#     answer2 = request.form['Q2']
#     answer3 = request.form['Q3']
#     answer4 = request.form['Q4']
#     answer5 = request.form['Q5']
#     zipcode = request.form['Q6']
#
#     answers = answer1 + " " + answer2 + " " + answer3 + " " + answer4 + " " + answer5
#
#     data = getSentiment(answers)
#
#     emotions = data["emotion"]["document"]["emotion"]
#
#     if emotions["anger"] > emotions["disgust"] and emotions["anger"] > emotions["fear"] and emotions["anger"] > emotions["joy"] and emotions["anger"] > emotions["sadness"]:
#     #Action, War, and Western to act as an outlet for the anger
#         genre_id = [0,15,16]
#
#     if emotions["disgust"] > emotions["anger"] and emotions["disgust"] > emotions["fear"] and emotions["disgust"] > emotions["joy"] and emotions["disgust"] > emotions["sadness"]:
#     #Crime, Documentary, and Romance to cater to different kinds of disgust the user may be feeling
#         genre_id = [4,5,12]
#
#
#     if emotions["fear"] > emotions["anger"] and emotions["fear"] > emotions["disgust"] and emotions["fear"] > emotions["joy"] and emotions["fear"] > emotions["sadness"]:
#     #Horror, Sci-Fi, and Thriller for the user already in a fearful mood
#         genre_id = [10,13,14]
#
#
#     if emotions["joy"] > emotions["anger"] and emotions["joy"] > emotions["fear"] and emotions["joy"] > emotions["disgust"] and emotions["joy"] > emotions["sadness"]:
#     #Animation, Comedy, and Family for the happy user
#         genre_id = [2,3,7]
#
#
#     else:
#     #If the user is sad, they get a variety of options -- Advernture, Drama, Foreign, and Mystery
#         genre_id = [1,6,8,11]
#
#     genres = [
#         {"id": "0", "title": "Action"},
#         {"id": "1", "title": "Adventure"},
#         {"id": "2", "title": "Animation"},
#         {"id": "3", "title": "Comedy"},
#         {"id": "4", "title": "Crime"},
#         {"id": "5", "title": "Documentary"},
#         {"id": "6", "title": "Drama"},
#         {"id": "7", "title": "Family"},
#         {"id": "8", "title": "Foreign"},
#         {"id": "9", "title": "History"},
#         {"id": "10", "title": "Horror"},
#         {"id": "11", "title": "Mystery"},
#         {"id": "12", "title": "Romance"},
#         {"id": "13", "title": "Science Fiction"},
#         {"id": "14", "title": "Thriller"},
#         {"id": "15", "title": "War"},
#         {"id": "16", "title": "Western"}
#         ]
#
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/cinemas"
#     parameters = {'city_id': '2215'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#
#     NYCcinemas = (requests.get(ishowtimes_url, params=parameters, headers=headers).json())['cinemas']
#
#
#
#     genres_ids = []
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '0'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre0 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre0_ids = [movie['id'] for movie in genre0]
#     genres_ids.append(genre0_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US', 'genre_ids': '1'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre1 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre1_ids = [movie['id'] for movie in genre1]
#     genres_ids.append(genre1_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '2'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre2 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre2_ids = [movie['id'] for movie in genre2]
#     genres_ids.append(genre2_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '3'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre3 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre3_ids = [movie['id'] for movie in genre3]
#     genres_ids.append(genre3_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '4'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre4 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre4_ids = [movie['id'] for movie in genre4]
#     genres_ids.append(genre4_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '5'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre5 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre5_ids = [movie['id'] for movie in genre5]
#     genres_ids.append(genre5_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '6'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre6 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre6_ids = [movie['id'] for movie in genre6]
#     genres_ids.append(genre6_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '7'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre7 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre7_ids = [movie['id'] for movie in genre7]
#     genres_ids.append(genre7_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '8'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre8 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre8_ids = [movie['id'] for movie in genre8]
#     genres_ids.append(genre8_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '10'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre10 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre10_ids = [movie['id'] for movie in genre10]
#     genres_ids.append(genre10_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '11'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre11 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre11_ids = [movie['id'] for movie in genre11]
#     genres_ids.append(genre11_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '12'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre12 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre12_ids = [movie['id'] for movie in genre12]
#     genres_ids.append(genre12_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '13'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre13 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre13_ids = [movie['id'] for movie in genre13]
#     genres_ids.append(genre13_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '14'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre14 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre14_ids = [movie['id'] for movie in genre14]
#     genres_ids.append(genre14_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '15'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre15 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre15_ids = [movie['id'] for movie in genre15]
#     genres_ids.append(genre15_ids)
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US','genre_ids': '16'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     genre16 = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     genre16_ids = [movie['id'] for movie in genre16]
#     genres_ids.append(genre16_ids)
#
#
#
#     ishowtimes_url = "https://api.internationalshowtimes.com/v4/movies/"
#     parameters = {'country': 'US'}
#     headers={"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#     movies_ids_titles = requests.get(ishowtimes_url, params=parameters, headers=headers).json()['movies']
#
#     zipcodes = [
#     ("10026", "10027", "10030", "10037", "10039"),
#     ("10001", "10011", "10018", "10019", "10020", "10036"),
#     ("10029", "10035"),
#     ("10010", "10016", "10017", "10022"),
#     ("10012", "10013", "10014"),
#     ("10004", "10005", "10006", "10007", "10038", "10280"),
#     ("10002", "10003", "10009"),
#     ("10021", "10028", "10044", "10065", "10075", "10128"),
#     ("10023", "10024", "10025"),
#     ("10031", "10032", "10033", "10034", "10040")
#     ]
#
#     if zipcode == '10013':
#         zip_list = zipcodes[5]
#     elif zipcode == '10012':
#         zip_list = zipcodes[6]
#     elif zipcode == '10029':
#         zip_list = zipcodes[7]
#     elif zipcode == '10035' or zip in zipcodes[9]:
#         zip_list = zipcodes[0]
#     elif zipcode == '10014':
#         zip_list = zipcodes[1]
#     else:
#         for neighborhood in zipcodes:
#             for code in neighborhood:
#                 if code == zipcode:
#                     zip_list = neighborhood
#
#     results = []
#
#     cinemas_in_neighborhood = []
#     for cinema in NYCcinemas:
#         for x in zip_list:
#             if cinema['location']['address']['zipcode'] == x:
#                 cinemas_in_neighborhood.append(cinema)
#
#     showtimes_in_neighborhood = []
#     for cinema in cinemas_in_neighborhood:
#         cinema_id = cinema['id']
#         ishowtimes_url = "https://api.internationalshowtimes.com/v4/showtimes/?cinema_id={}".format(cinema_id)
#         headers = {"X-API-Key": "pAnHCJdI8kzQKglyyhtJoUvV2rGnWDOR"}
#         cinema_showtimes = requests.get(ishowtimes_url,headers = headers).json()['showtimes']
#         showtimes_in_neighborhood.append(cinema_showtimes)
#
#
#     genres_showtimes_in_neighborhood = []
#     for genre in genres_ids:
#         genre_showtimes_in_neighborhood = []
#
#         for cinema in showtimes_in_neighborhood:
#             for movie in cinema:
#                 criterion1 = movie['movie_id'] in genre
#                 criterion2 = movie['start_at'].startswith(datetime.now(tz=est).strftime('%Y-%m-%d'))
#                 criterion3 = est.localize(datetime.strptime(movie['start_at'],'%Y-%m-%dT%H:%M:%S-04:00'))> datetime.now(tz=est)
#                 if criterion1 and criterion2 and criterion3:
#                     genre_showtimes_in_neighborhood.append(movie)
#
#         genres_showtimes_in_neighborhood.append(genre_showtimes_in_neighborhood)
#
#
#     for genre in genre_id:
#         if genre >= 10:
#             genre -= 1
#         for showtime in genres_showtimes_in_neighborhood[genre]:
#             info = {}
#
#             for movie in movies_ids_titles:
#                 if movie['id'] == showtime['movie_id']:
#                     info['Title'] = movie['title']
#                     info["Poster link"] = movie['poster_image_thumbnail']
#
#             for cinema in cinemas_in_neighborhood:
#                 if cinema['id'] == showtime['cinema_id']:
#                     info['Cinema'] = cinema['name']
#                     info["Location"] = cinema['location']['address']['display_text']
#
#             info["Start at"] = showtime['start_at'].replace("T", " ").replace("-04:00","")
#             if not info in results:
#                 results.append(info)
#
#     if len(results) > 0:
#         results = pd.DataFrame(results).sort_values(by = 'Start at')
#     else:
#         results = pd.DataFrame(results)
#
#
#     return render_template("output.html", results = results)
#
#
# def getSentiment(text):
#     #We're using the IBM Watson API to perform a sentiment analysis
#     endpoint = "https://gateway.watsonplatform.net/natural-language-understanding/api/v1/analyze"
#
#
#     username = "25a70137-e1e3-4e34-8ca3-daffb770c96b"
#     password = "4NrzHVNT7KBj"
#
#     parameters = {
#         #'features' : 'concepts,categories,emotion,entities,keywords,metadata,relations,semantic_roles,sentiment',
#         'features': 'emotion,sentiment',
#         'version' : '2017-03-16',
#         'text': text,
#         'language' : 'en',
#         # url = url_to_analyze, this is an alternative to sending the text
#     }
#
#     resp = requests.get(endpoint, params=parameters, auth=(username, password))
#
#     return resp.json()
# if __name__ == '__main__':
#     app.run(host='0.0.0.0', port=5000, debug=True)
#
# ```

# %% [markdown]
# ## user_inputs.html
# Found in the templates folder under PPDS_Final_Project (the title of our project folder in jupyter)

# %% [markdown]
# File 'user_inputs.html' in folder 'templates'
#
# ```html
# <!DOCTYPE html>
#
# <html>
#  <table height="100%" width="100%" cellpadding="0" cellspacing="0" border="0">
#    <tr>
#      <td valign="top" align="left" background="https://images.unsplash.com/photo-1521021153866-f8089b0aa617?ixlib=rb-0.3.5&ixid=eyJhcHBfaWQiOjEyMDd9&s=94418b9bd265c9b30fd8c1f58dd9515c&auto=format&fit=crop&w=1350&q=80">
#     <head>
#     <h1 style="color: #FFFFFF">&nbsp;Welcome to Movie Genie</h1>
#     <h3 style="color: #FFFFFF">&nbsp;&nbsp;Answer the following questions so we can help you plan your perfect night!</h3>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">
# </head>
# <body>
#
#       <form action = "http://52.204.127.21:5000/result" method = "POST">
#           <p style="color: #FFFFFF">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;What is the most interesting thing that has happened to you today?</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<input type="text" name="Q1"></p>
#           <p style="color: #FFFFFF">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;What are you looking forward to later?</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<input type="text" name="Q2"></p>
#           <p style="color: #FFFFFF">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;If you could be granted one wish, what would you wish for? </p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<input type="text" name="Q3"></p>
#           <p style="color: #FFFFFF">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Describe the weather today.</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<input type="text" name="Q4"></p>
#           <p style="color: #FFFFFF">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;How are you feeling today?</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<input type="text" name="Q5"></p>
#           <p style="color: #FFFFFF">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lastly, what is your zip code?</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<input type="text" name="Q6"></p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<input type="submit">
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#           <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</p>
#
#       </form>
#
#
# </body>
# </td>
#    </tr>
#  </table>
# </html>
# ```

# %% [markdown]
# ## output.html
# This file formats the pandas dataframe displayed to the user when they get their results.

# %% [markdown]
# File 'output.html' in folder 'templates'
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">
# </head>
# <body>
#     <div class="container">
#         <div class="panel panel-info">
#             <div class="panel-heading">
#                 {% if results|length == 0 %}
#                         <p>Sorry, there are no more shows today in your area to fit your mood.</p>
#                 {% else %}
#                     <h1 class="panel-title">The perfect movies for your mood: </h1>
#             </div>
#             <table  class="table table-striped table-bordered table-hover">
#                 <thead>
#                      <tr>    <!-- Construct table header -->
#                             <th> Title </th>
#                             <th> Start at </th>
#                             <th> Cinema </th>
#                             <th> Location </th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#
#
#                          {% for index, row in results.iterrows() %}
#                         <tr>
#                             <td>{{ row['Title'] }}</td>
#                             <td>{{ row['Start at'] }}</td>
#                             <td>{{ row['Cinema'] }}</td>
#                             <td>{{ row['Location'] }}</td>
#                         </tr>
#                     {% endfor %}
#
#                     {% endif %}
#
#                      </tbody>
#              </table>
#         </div>
#     </div>
# </body>
# </html>
# ```

# %% [markdown]
# Going forward, we would want to find a faster and easier to use API to make the user experience better,  and we would want a more detailed sentiment analysis to truly specialize the movie selections for your mood.  We think this could also be expanded to recommending certain restaurants or Airbnbs based on your mood or personality.  But for now, Movie Genie can be a helpful way for users to more easily plan their trip to the movies.
